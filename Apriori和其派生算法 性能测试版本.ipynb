# %%
# frozenset() 返回一个冻结的集合，冻结后集合不能再添加或删除任何元素。
import numpy as np
import pandas as pd


def loadDataSet():
    '''创建一个用于测试的简单的数据集'''

    data = pd.read_csv("train.csv")
    data = data.sample(1000)
#     import copy
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data)) # 将数据扩大8倍
    print(data.shape)
    def gerDoodAndBad(score):
        ans = []

        # math judge
        if score['math score'] > 80:
            ans.append('MG')
        elif score['math score'] < 60:
            ans.append('MB')

        # reading judge
        if score['reading score'] > 85:
            ans.append('RG')
        elif score['reading score'] < 50:
            ans.append('RB')

        # writing judge
        if score['writing score'] > 85:
            ans.append('WG')
        elif score['writing score'] < 50:
            ans.append('WB')

        if score['test preparation course'] == 1:
            ans.append("preparation")

        return ans

    data['Apriori'] = data.apply(lambda x: gerDoodAndBad(x), axis=1)
#     print(data.head())

    return np.array(data['Apriori'])


def loadTest():
    testD = pd.read_csv('testData')
    testD = testD.sample(500)
    print(testD.shape)
    npt = np.array(testD)
    npt
    return npt


# 返回只有单个元素的候选集
def createC1(dataSet):
    '''
        构建初始候选项集的列表，即所有候选项集只包含一个元素，
        C1是大小为1的所有候选项集的集合
    '''
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if [item] not in C1:
                C1.append([item])
    C1.sort()
    # return map( frozenset, C1 )
    # return [var for var in map(frozenset,C1)]
    return [frozenset(var) for var in C1]


def scanD(D, Ck, minSupport):
    '''
        计算Ck中的项集在数据集合D(记录或者transactions)中的支持度,
        返回满足最小支持度的项集的集合，和所有项集支持度信息的字典。
    '''
    print(len(Ck))
    ssCnt = {}
    for tid in D:  # 对于每一条transaction
        for can in Ck:  # 对于每一个候选项集can，检查是否是transaction的一部分 # 即该候选can是否得到transaction的支持
            flag = True
            for i in can:
                if i not in tid:
                    flag = False
                    
            if flag:
                ssCnt[can] = ssCnt.get(can, 0) + 1
                
#             if can.issubset(tid):
#                 ssCnt[can] = ssCnt.get(can, 0) + 1
    numItems = float(len(D))
    # print("ssCnt is",ssCnt)
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key] / numItems  # 每个项集的支持度
        if support >= minSupport:  # 将满足最小支持度的项集，加入retList
            retList.insert(0, key)
        supportData[key] = support  # 汇总支持度数据
    return retList, supportData


def aprioriGen(Lk, k):  # Aprior算法
    '''
        由初始候选项集的集合Lk生成新的生成候选项集，
        k表示生成的新项集中所含有的元素个数
        注意其生成的过程中，首选对每个项集按元素排序，然后每次比较两个项集，只有在前k-1项相同时才将这两项合并。这样做是因为函数并非要两两合并各个集合，那样生成的集合并非都是k+1项的。在限制项数为k+1的前提下，只有在前k-1项相同、最后一项不相同的情况下合并才为所需要的新候选项集。
    '''
    retList = set()
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i + 1, lenLk):
            
            L1 = Lk[i]
            L2 = Lk[j]
            cnt =0
            for m in L1:
                if m in L2:
                    cnt+=1
            if cnt == k-2:
                retList.add(Lk[i] | Lk[j])
    return retList


def apriori(dataSet, minSupport=0.5):
    """
    该函数为Apriori算法的主函数，按照前述伪代码的逻辑执行。Ck表示项数为k的候选项集，最初的C1通过createC1()函数生成。Lk表示项数为k的频繁项集，supK为其支持度，Lk和supK由scanD()函数通过Ck计算而来。
    :param dataSet:
    :param minSupport:
    :return:
    """
    C1 = createC1(
        dataSet)  # 构建初始候选项集C1  [frozenset({1}), frozenset({2}), frozenset({3}), frozenset({4}), frozenset({5})]

    D = [set(var) for var in dataSet]  # 集合化数据集
    L1, suppData = scanD(D, C1, minSupport)  # 构建初始的频繁项集，即所有项集只有一个元素
    L = [L1]  # 最初的L1中的每个项集含有一个元素，新生成的
    # print()
    k = 2  # 项集应该含有2个元素，所以 k=2

    while (len(L[k - 2]) > 0):
        t = time.time()
        Ck = aprioriGen(L[k - 2], k)
        print(f'gen coast:{time.time() - t:.8f}s')
        
        t = time.time()
        Lk, supK = scanD(D, Ck, minSupport) # 筛选最小支持度的频繁项集
        print(f'scan coast:{time.time() - t:.8f}s')
        # print("iter is ")
        # print(Ck)
        # print(Lk)
        # print()
        suppData.update(supK)  # 将新的项集的支持度数据加入原来的总支持度字典中
        L.append(Lk)  # 将符合最小支持度要求的项集加入L
        k += 1  # 新生成的项集中的元素个数应不断增加
    return L, suppData  # 返回所有满足条件的频繁项集的列表，和所有候选项集的支持度信息


def calcConf(freqSet, H, supportData, brl, minConf=0.7):  # 规则生成与评价
    '''
        计算规则的可信度，返回满足最小可信度的规则。
        freqSet(frozenset):频繁项集
        H(frozenset):频繁项集中所有的元素
        supportData(dic):频繁项集中所有元素的支持度
        brl(tuple):满足可信度条件的关联规则
        minConf(float):最小可信度
    '''
    prunedH = []
    for conseq in H:
        conf = supportData[freqSet] / supportData[freqSet - conseq]
        if conf >= minConf:
            print(freqSet - conseq, '-->', conseq, 'conf:', conf)
            brl.append((freqSet - conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH


def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    '''
        对频繁项集中元素超过2的项集进行合并。
        freqSet(frozenset):频繁项集
        H(frozenset):频繁项集中的所有元素，即可以出现在规则右部的元素
        supportData(dict):所有项集的支持度信息
        brl(tuple):生成的规则
    '''
    m = len(H[0])
    if len(freqSet) > m + 1:  # 查看频繁项集是否足够大，以到于移除大小为 m的子集，否则继续生成m+1大小的频繁项集
        Hmp1 = aprioriGen(H, m + 1)
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)  # 对于新生成的m+1大小的频繁项集，计算新生成的关联规则的右则的集合
        if len(Hmp1) > 1:  # 如果不止一条规则满足要求（新生成的关联规则的右则的集合的大小大于1），进一步递归合并，
            # 这样做的结果就是会有“[1|多]->多”(右边只会是“多”，因为合并的本质是频繁子项集变大，
            # 而calcConf函数的关联结果的右侧就是频繁子项集）的关联结果
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)


def generateRules(L, supportData, minConf=0.7):
    '''
        根据频繁项集和最小可信度生成规则。
        L(list):存储频繁项集
        supportData(dict):存储着所有项集（不仅仅是频繁项集）的支持度
        minConf(float):最小可信度
    '''
    bigRuleList = []
    for i in range(1, len(L)):
        for freqSet in L[i]:  # 对于每一个频繁项集的集合freqSet
            H1 = [frozenset([item]) for item in freqSet]
            if i > 1:  # 如果频繁项集中的元素个数大于2，需要进一步合并，这样做的结果就是会有“[1|多]->多”(右边只会是“多”，
                # 因为合并的本质是频繁子项集变大，而calcConf函数的关联结果的右侧就是频繁子项集），的关联结果
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)

    sorted(bigRuleList)
    return bigRuleList

# %%
myDat = loadTest()  # 导入数据集
# Out:
# (500, 23)

# %%
import time
t = time.time()

L, suppData = apriori(myDat, 0.3)  # 选择频繁项集
# print(u"频繁项集L：", suppData)
# print(u"所有候选项集的支持度信息：", suppData)
print(f'花费的时间为:{time.time() - t:.8f}s')
# Out:
# 23
# gen coast:0.00000000s
# 153
# scan coast:0.10423231s
# gen coast:0.00799489s
# 687
# scan coast:0.40059590s
# gen coast:0.11188436s
# 1869
# scan coast:1.27302551s
# gen coast:0.63244438s
# 3323
# scan coast:2.40807414s
# gen coast:1.41571140s
# 4006
# scan coast:3.08484769s
# gen coast:1.82767606s
# 3331
# scan coast:2.87494159s
# gen coast:1.15157700s
# 1925
# scan coast:1.53290915s
# gen coast:0.25651121s
# 771
# scan coast:0.60928965s
# gen coast:0.03193426s
# 205
# scan coast:0.17662835s
# gen coast:0.00794458s
# 30
# scan coast:0.02401805s
# gen coast:0.00000000s
# 1
# scan coast:0.00000000s
# 花费的时间为:17.97748756s

# %%
rules = generateRules(L, suppData, minConf=0.9)
print('rules:\n', rules)

# %%
L, suppData
# Out:
# ([[frozenset({'v'}),
#    frozenset({'t'}),
#    frozenset({'s'}),
#    frozenset({'y'}),
#    frozenset({'x'}),
#    frozenset({'w'}),
#    frozenset({'p'}),
#    frozenset({'o'}),
#    frozenset({'n'}),
#    frozenset({'l'}),
#    frozenset({'k'}),
#    frozenset({'g'}),
#    frozenset({'f'}),
#    frozenset({'e'}),
#    frozenset({'d'}),
#    frozenset({'c'}),
#    frozenset({'b'})],
#   [frozenset({'d', 's'}),
#    frozenset({'g', 's'}),
#    frozenset({'g', 't'}),
#    frozenset({'k', 's'}),
#    frozenset({'k', 't'}),
#    frozenset({'k', 'v'}),
#    frozenset({'b', 's'}),
#    frozenset({'c', 's'}),
#    frozenset({'e', 's'}),
#    frozenset({'f', 's'}),
#    frozenset({'n', 's'}),
#    frozenset({'o', 's'}),
#    frozenset({'p', 's'}),
#    frozenset({'s', 'w'}),
#    frozenset({'s', 'x'}),
#    frozenset({'s', 'y'}),
#    frozenset({'b', 't'}),
#    frozenset({'c', 't'}),
#    frozenset({'e', 't'}),
#    frozenset({'f', 't'}),
#    frozenset({'n', 't'}),
#    frozenset({'o', 't'}),
#    frozenset({'p', 't'}),
#    frozenset({'t', 'w'}),
#    frozenset({'t', 'x'}),
#    frozenset({'t', 'y'}),
#    frozenset({'s', 't'}),
#    frozenset({'b', 'v'}),
#    frozenset({'c', 'v'}),
#    frozenset({'e', 'v'}),
#    frozenset({'f', 'v'}),
#    frozenset({'n', 'v'}),
#    frozenset({'o', 'v'}),
#    frozenset({'p', 'v'}),
#    frozenset({'v', 'w'}),
#    frozenset({'s', 'v'}),
#    frozenset({'t', 'v'}),
#    frozenset({'b', 'c'}),
#    frozenset({'b', 'd'}),
#    frozenset({'c', 'd'}),
#    frozenset({'b', 'e'}),
#    frozenset({'c', 'e'}),
#    frozenset({'d', 'e'}),
#    frozenset({'b', 'f'}),
#    frozenset({'c', 'f'}),
#    frozenset({'d', 'f'}),
#    frozenset({'e', 'f'}),
#    frozenset({'b', 'g'}),
#    frozenset({'c', 'g'}),
#    frozenset({'e', 'g'}),
#    frozenset({'f', 'g'}),
#    frozenset({'b', 'k'}),
#    frozenset({'c', 'k'}),
#    frozenset({'e', 'k'}),
#    frozenset({'f', 'k'}),
#    frozenset({'g', 'k'}),
#    frozenset({'b', 'l'}),
#    frozenset({'c', 'l'}),
#    frozenset({'e', 'l'}),
#    frozenset({'f', 'l'}),
#    frozenset({'b', 'n'}),
#    frozenset({'c', 'n'}),
#    frozenset({'d', 'n'}),
#    frozenset({'e', 'n'}),
#    frozenset({'f', 'n'}),
#    frozenset({'g', 'n'}),
#    frozenset({'k', 'n'}),
#    frozenset({'b', 'o'}),
#    frozenset({'c', 'o'}),
#    frozenset({'d', 'o'}),
#    frozenset({'e', 'o'}),
#    frozenset({'f', 'o'}),
#    frozenset({'g', 'o'}),
#    frozenset({'k', 'o'}),
#    frozenset({'l', 'o'}),
#    frozenset({'n', 'o'}),
#    frozenset({'b', 'p'}),
#    frozenset({'c', 'p'}),
#    frozenset({'d', 'p'}),
#    frozenset({'e', 'p'}),
#    frozenset({'f', 'p'}),
#    frozenset({'g', 'p'}),
#    frozenset({'k', 'p'}),
#    frozenset({'l', 'p'}),
#    frozenset({'n', 'p'}),
#    frozenset({'o', 'p'}),
#    frozenset({'b', 'w'}),
#    frozenset({'c', 'w'}),
#    frozenset({'d', 'w'}),
#    frozenset({'e', 'w'}),
#    frozenset({'f', 'w'}),
#    frozenset({'g', 'w'}),
#    frozenset({'k', 'w'}),
#    frozenset({'l', 'w'}),
#    frozenset({'n', 'w'}),
#    frozenset({'o', 'w'}),
#    frozenset({'p', 'w'}),
#    frozenset({'b', 'x'}),
#    frozenset({'c', 'x'}),
#    frozenset({'e', 'x'}),
#    frozenset({'f', 'x'}),
#    frozenset({'k', 'x'}),
#    frozenset({'n', 'x'}),
#    frozenset({'o', 'x'}),
#    frozenset({'p', 'x'}),
#    frozenset({'w', 'x'}),
#    frozenset({'b', 'y'}),
#    frozenset({'c', 'y'}),
#    frozenset({'e', 'y'}),
#    frozenset({'f', 'y'}),
#    frozenset({'k', 'y'}),
#    frozenset({'n', 'y'}),
#    frozenset({'o', 'y'}),
#    frozenset({'p', 'y'}),
#    frozenset({'w', 'y'})],
#   [frozenset({'g', 's', 'w'}),
#    frozenset({'d', 's', 'w'}),
#    frozenset({'g', 's', 't'}),
#    frozenset({'g', 't', 'w'}),
#    frozenset({'g', 'p', 't'}),
#    frozenset({'g', 'o', 't'}),
#    frozenset({'g', 'n', 't'}),
#    frozenset({'f', 'g', 't'}),
#    frozenset({'e', 'g', 't'}),
#    frozenset({'b', 'g', 't'}),
#    frozenset({'g', 'p', 's'}),
#    frozenset({'g', 'o', 's'}),
#    frozenset({'g', 'n', 's'}),
#    frozenset({'f', 'g', 's'}),
#    frozenset({'e', 'g', 's'}),
#    frozenset({'b', 'g', 's'}),
#    frozenset({'d', 'p', 's'}),
#    frozenset({'d', 'o', 's'}),
#    frozenset({'d', 'n', 's'}),
#    frozenset({'d', 'f', 's'}),
#    frozenset({'d', 'e', 's'}),
#    frozenset({'b', 'd', 's'}),
#    frozenset({'k', 's', 'w'}),
#    frozenset({'k', 's', 't'}),
#    frozenset({'k', 't', 'w'}),
#    frozenset({'k', 'p', 't'}),
#    frozenset({'k', 'o', 't'}),
#    frozenset({'k', 'n', 't'}),
#    frozenset({'f', 'k', 't'}),
#    frozenset({'e', 'k', 't'}),
#    frozenset({'c', 'k', 't'}),
#    frozenset({'b', 'k', 't'}),
#    frozenset({'k', 'p', 's'}),
#    frozenset({'k', 'o', 's'}),
#    frozenset({'k', 'n', 's'}),
#    frozenset({'f', 'k', 's'}),
#    frozenset({'e', 'k', 's'}),
#    frozenset({'c', 'k', 's'}),
#    frozenset({'b', 'k', 's'}),
#    frozenset({'k', 'v', 'w'}),
#    frozenset({'e', 'k', 'v'}),
#    frozenset({'k', 'p', 'v'}),
#    frozenset({'k', 'o', 'v'}),
#    frozenset({'f', 'k', 'v'}),
#    frozenset({'c', 'k', 'v'}),
#    frozenset({'b', 'k', 'v'}),
#    frozenset({'p', 'v', 'w'}),
#    frozenset({'o', 'v', 'w'}),
#    frozenset({'n', 'v', 'w'}),
#    frozenset({'f', 'v', 'w'}),
#    frozenset({'e', 'v', 'w'}),
#    frozenset({'c', 'v', 'w'}),
#    frozenset({'b', 'v', 'w'}),
#    frozenset({'o', 'p', 'v'}),
#    frozenset({'f', 'p', 'v'}),
#    frozenset({'c', 'p', 'v'}),
#    frozenset({'b', 'p', 'v'}),
#    frozenset({'n', 'p', 'v'}),
#    frozenset({'n', 'o', 'v'}),
#    frozenset({'f', 'n', 'v'}),
#    frozenset({'e', 'n', 'v'}),
#    frozenset({'c', 'n', 'v'}),
#    frozenset({'b', 'n', 'v'}),
#    frozenset({'f', 'o', 'v'}),
#    frozenset({'e', 'p', 'v'}),
#    frozenset({'e', 'o', 'v'}),
#    frozenset({'e', 'f', 'v'}),
#    frozenset({'c', 'e', 'v'}),
#    frozenset({'b', 'e', 'v'}),
#    frozenset({'c', 'o', 'v'}),
#    frozenset({'c', 'f', 'v'}),
#    frozenset({'b', 'c', 'v'}),
#    frozenset({'b', 'o', 'v'}),
#    frozenset({'b', 'f', 'v'}),
#    frozenset({'s', 't', 'v'}),
#    frozenset({'s', 't', 'y'}),
#    frozenset({'t', 'w', 'x'}),
#    frozenset({'p', 't', 'x'}),
#    frozenset({'o', 't', 'x'}),
#    frozenset({'n', 't', 'x'}),
#    frozenset({'f', 't', 'x'}),
#    frozenset({'e', 't', 'x'}),
#    frozenset({'b', 't', 'x'}),
#    frozenset({'t', 'v', 'w'}),
#    frozenset({'s', 't', 'w'}),
#    frozenset({'t', 'w', 'y'}),
#    frozenset({'p', 't', 'v'}),
#    frozenset({'p', 's', 't'}),
#    frozenset({'p', 't', 'y'}),
#    frozenset({'p', 't', 'w'}),
#    frozenset({'o', 't', 'v'}),
#    frozenset({'o', 's', 't'}),
#    frozenset({'o', 't', 'y'}),
#    frozenset({'o', 't', 'w'}),
#    frozenset({'o', 'p', 't'}),
#    frozenset({'n', 't', 'v'}),
#    frozenset({'n', 's', 't'}),
#    frozenset({'n', 't', 'y'}),
#    frozenset({'n', 't', 'w'}),
#    frozenset({'n', 'p', 't'}),
#    frozenset({'n', 'o', 't'}),
#    frozenset({'f', 't', 'v'}),
#    frozenset({'f', 's', 't'}),
#    frozenset({'f', 't', 'y'}),
#    frozenset({'f', 't', 'w'}),
#    frozenset({'f', 'p', 't'}),
#    frozenset({'f', 'o', 't'}),
#    frozenset({'f', 'n', 't'}),
#    frozenset({'e', 't', 'v'}),
#    frozenset({'e', 's', 't'}),
#    frozenset({'e', 't', 'y'}),
#    frozenset({'e', 't', 'w'}),
#    frozenset({'e', 'p', 't'}),
#    frozenset({'e', 'o', 't'}),
#    frozenset({'e', 'n', 't'}),
#    frozenset({'e', 'f', 't'}),
#    frozenset({'c', 't', 'v'}),
#    frozenset({'c', 's', 't'}),
#    frozenset({'c', 't', 'y'}),
#    frozenset({'c', 't', 'w'}),
#    frozenset({'c', 'p', 't'}),
#    frozenset({'c', 'o', 't'}),
#    frozenset({'c', 'n', 't'}),
#    frozenset({'c', 'f', 't'}),
#    frozenset({'c', 'e', 't'}),
#    frozenset({'b', 't', 'v'}),
#    frozenset({'b', 's', 't'}),
#    frozenset({'b', 't', 'y'}),
#    frozenset({'b', 't', 'w'}),
#    frozenset({'b', 'p', 't'}),
#    frozenset({'b', 'o', 't'}),
#    frozenset({'b', 'n', 't'}),
#    frozenset({'b', 'f', 't'}),
#    frozenset({'b', 'e', 't'}),
#    frozenset({'b', 'c', 't'}),
#    frozenset({'s', 'w', 'x'}),
#    frozenset({'p', 's', 'x'}),
#    frozenset({'o', 's', 'x'}),
#    frozenset({'n', 's', 'x'}),
#    frozenset({'f', 's', 'x'}),
#    frozenset({'e', 's', 'x'}),
#    frozenset({'c', 's', 'x'}),
#    frozenset({'b', 's', 'x'}),
#    frozenset({'s', 't', 'x'}),
#    frozenset({'s', 'w', 'y'}),
#    frozenset({'p', 's', 'w'}),
#    frozenset({'o', 's', 'w'}),
#    frozenset({'n', 's', 'w'}),
#    frozenset({'f', 's', 'w'}),
#    frozenset({'e', 's', 'w'}),
#    frozenset({'c', 's', 'w'}),
#    frozenset({'b', 's', 'w'}),
#    frozenset({'s', 'v', 'w'}),
#    frozenset({'p', 's', 'v'}),
#    frozenset({'p', 's', 'y'}),
#    frozenset({'o', 's', 'v'}),
#    frozenset({'o', 's', 'y'}),
#    frozenset({'o', 'p', 's'}),
#    frozenset({'n', 's', 'v'}),
#    frozenset({'n', 's', 'y'}),
#    frozenset({'n', 'p', 's'}),
#    frozenset({'n', 'o', 's'}),
#    frozenset({'f', 's', 'v'}),
#    frozenset({'f', 's', 'y'}),
#    frozenset({'f', 'p', 's'}),
#    frozenset({'f', 'o', 's'}),
#    frozenset({'f', 'n', 's'}),
#    frozenset({'e', 's', 'v'}),
#    frozenset({'e', 's', 'y'}),
#    frozenset({'e', 'p', 's'}),
#    frozenset({'e', 'o', 's'}),
#    frozenset({'e', 'n', 's'}),
#    frozenset({'e', 'f', 's'}),
#    frozenset({'c', 's', 'v'}),
#    frozenset({'c', 's', 'y'}),
#    frozenset({'c', 'p', 's'}),
#    frozenset({'c', 'o', 's'}),
#    frozenset({'c', 'n', 's'}),
#    frozenset({'c', 'f', 's'}),
#    frozenset({'c', 'e', 's'}),
#    frozenset({'b', 's', 'v'}),
#    frozenset({'b', 's', 'y'}),
#    frozenset({'b', 'p', 's'}),
#    frozenset({'b', 'o', 's'}),
#    frozenset({'b', 'n', 's'}),
#    frozenset({'b', 'f', 's'}),
#    frozenset({'b', 'e', 's'}),
#    frozenset({'b', 'c', 's'}),
#    frozenset({'p', 'w', 'x'}),
#    frozenset({'o', 'w', 'x'}),
#    frozenset({'o', 'p', 'x'}),
#    frozenset({'n', 'w', 'x'}),
#    frozenset({'n', 'p', 'x'}),
#    frozenset({'n', 'o', 'x'}),
#    frozenset({'k', 'w', 'x'}),
#    frozenset({'k', 'p', 'x'}),
#    frozenset({'k', 'o', 'x'}),
#    frozenset({'f', 'w', 'x'}),
#    frozenset({'f', 'p', 'x'}),
#    frozenset({'f', 'o', 'x'}),
#    frozenset({'f', 'n', 'x'}),
#    frozenset({'f', 'k', 'x'}),
#    frozenset({'e', 'w', 'x'}),
#    frozenset({'e', 'p', 'x'}),
#    frozenset({'e', 'o', 'x'}),
#    frozenset({'e', 'n', 'x'}),
#    frozenset({'e', 'k', 'x'}),
#    frozenset({'e', 'f', 'x'}),
#    frozenset({'c', 'w', 'x'}),
#    frozenset({'c', 'p', 'x'}),
#    frozenset({'c', 'o', 'x'}),
#    frozenset({'c', 'n', 'x'}),
#    frozenset({'c', 'f', 'x'}),
#    frozenset({'c', 'e', 'x'}),
#    frozenset({'b', 'w', 'x'}),
#    frozenset({'b', 'p', 'x'}),
#    frozenset({'b', 'o', 'x'}),
#    frozenset({'b', 'n', 'x'}),
#    frozenset({'b', 'k', 'x'}),
#    frozenset({'b', 'f', 'x'}),
#    frozenset({'b', 'e', 'x'}),
#    frozenset({'b', 'c', 'x'}),
#    frozenset({'p', 'w', 'y'}),
#    frozenset({'o', 'w', 'y'}),
#    frozenset({'o', 'p', 'w'}),
#    frozenset({'n', 'w', 'y'}),
#    frozenset({'n', 'p', 'w'}),
#    frozenset({'n', 'o', 'w'}),
#    frozenset({'l', 'p', 'w'}),
#    frozenset({'l', 'o', 'w'}),
#    frozenset({'k', 'w', 'y'}),
#    frozenset({'k', 'p', 'w'}),
#    frozenset({'k', 'o', 'w'}),
#    frozenset({'k', 'n', 'w'}),
#    frozenset({'g', 'p', 'w'}),
#    frozenset({'g', 'o', 'w'}),
#    frozenset({'g', 'n', 'w'}),
#    frozenset({'g', 'k', 'w'}),
#    frozenset({'f', 'w', 'y'}),
#    frozenset({'f', 'p', 'w'}),
#    frozenset({'f', 'o', 'w'}),
#    frozenset({'f', 'n', 'w'}),
#    frozenset({'f', 'l', 'w'}),
#    frozenset({'f', 'k', 'w'}),
#    frozenset({'f', 'g', 'w'}),
#    frozenset({'e', 'w', 'y'}),
#    frozenset({'e', 'p', 'w'}),
#    frozenset({'e', 'o', 'w'}),
#    frozenset({'e', 'n', 'w'}),
#    frozenset({'e', 'l', 'w'}),
#    frozenset({'e', 'k', 'w'}),
#    frozenset({'e', 'g', 'w'}),
#    frozenset({'e', 'f', 'w'}),
#    frozenset({'d', 'p', 'w'}),
#    frozenset({'d', 'o', 'w'}),
#    frozenset({'d', 'n', 'w'}),
#    frozenset({'d', 'f', 'w'}),
#    frozenset({'d', 'e', 'w'}),
#    frozenset({'c', 'w', 'y'}),
#    frozenset({'c', 'p', 'w'}),
#    frozenset({'c', 'o', 'w'}),
#    frozenset({'c', 'n', 'w'}),
#    frozenset({'c', 'k', 'w'}),
#    frozenset({'c', 'g', 'w'}),
#    frozenset({'c', 'f', 'w'}),
#    frozenset({'c', 'e', 'w'}),
#    frozenset({'c', 'd', 'w'}),
#    frozenset({'b', 'w', 'y'}),
#    frozenset({'b', 'p', 'w'}),
#    frozenset({'b', 'o', 'w'}),
#    frozenset({'b', 'n', 'w'}),
#    frozenset({'b', 'l', 'w'}),
#    frozenset({'b', 'k', 'w'}),
#    frozenset({'b', 'g', 'w'}),
#    frozenset({'b', 'f', 'w'}),
#    frozenset({'b', 'e', 'w'}),
#    frozenset({'b', 'd', 'w'}),
#    frozenset({'b', 'c', 'w'}),
#    frozenset({'o', 'p', 'y'}),
#    frozenset({'n', 'p', 'y'}),
#    frozenset({'l', 'o', 'p'}),
#    frozenset({'k', 'p', 'y'}),
#    frozenset({'g', 'o', 'p'}),
#    frozenset({'f', 'p', 'y'}),
#    frozenset({'f', 'o', 'p'}),
#    frozenset({'f', 'l', 'p'}),
#    frozenset({'f', 'g', 'p'}),
#    frozenset({'e', 'p', 'y'}),
#    frozenset({'c', 'p', 'y'}),
#    frozenset({'c', 'o', 'p'}),
#    frozenset({'c', 'l', 'p'}),
#    frozenset({'c', 'g', 'p'}),
#    frozenset({'c', 'f', 'p'}),
#    frozenset({'b', 'p', 'y'}),
#    frozenset({'b', 'o', 'p'}),
#    frozenset({'b', 'l', 'p'}),
#    frozenset({'b', 'g', 'p'}),
#    frozenset({'b', 'f', 'p'}),
#    frozenset({'b', 'c', 'p'}),
#    frozenset({'n', 'o', 'y'}),
#    frozenset({'n', 'o', 'p'}),
#    frozenset({'k', 'o', 'y'}),
#    frozenset({'k', 'o', 'p'}),
#    frozenset({'f', 'o', 'y'}),
#    frozenset({'e', 'o', 'y'}),
#    frozenset({'e', 'o', 'p'}),
#    frozenset({'d', 'o', 'p'}),
#    frozenset({'c', 'o', 'y'}),
#    frozenset({'b', 'o', 'y'}),
#    frozenset({'k', 'n', 'y'}),
#    frozenset({'k', 'n', 'p'}),
#    frozenset({'k', 'n', 'o'}),
#    frozenset({'g', 'n', 'p'}),
#    frozenset({'g', 'n', 'o'}),
#    frozenset({'f', 'n', 'y'}),
#    frozenset({'f', 'n', 'p'}),
#    frozenset({'f', 'n', 'o'}),
#    frozenset({'f', 'k', 'n'}),
#    frozenset({'f', 'g', 'n'}),
#    frozenset({'e', 'n', 'y'}),
#    frozenset({'e', 'n', 'p'}),
#    frozenset({'e', 'n', 'o'}),
#    frozenset({'e', 'k', 'n'}),
#    frozenset({'e', 'g', 'n'}),
#    frozenset({'e', 'f', 'n'}),
#    frozenset({'d', 'n', 'p'}),
#    frozenset({'d', 'n', 'o'}),
#    frozenset({'d', 'f', 'n'}),
#    frozenset({'d', 'e', 'n'}),
#    frozenset({'c', 'n', 'y'}),
#    frozenset({'c', 'n', 'p'}),
#    frozenset({'c', 'n', 'o'}),
#    frozenset({'c', 'k', 'n'}),
#    frozenset({'c', 'g', 'n'}),
#    frozenset({'c', 'f', 'n'}),
#    frozenset({'c', 'e', 'n'}),
#    frozenset({'c', 'd', 'n'}),
#    frozenset({'b', 'n', 'y'}),
#    frozenset({'b', 'n', 'p'}),
#    frozenset({'b', 'n', 'o'}),
#    frozenset({'b', 'k', 'n'}),
#    frozenset({'b', 'g', 'n'}),
#    frozenset({'b', 'f', 'n'}),
#    frozenset({'b', 'e', 'n'}),
#    frozenset({'b', 'd', 'n'}),
#    frozenset({'b', 'c', 'n'}),
#    frozenset({'f', 'l', 'o'}),
#    frozenset({'e', 'l', 'p'}),
#    frozenset({'e', 'l', 'o'}),
#    frozenset({'c', 'l', 'o'}),
#    frozenset({'b', 'l', 'o'}),
#    frozenset({'g', 'k', 'p'}),
#    frozenset({'g', 'k', 'o'}),
#    frozenset({'f', 'k', 'y'}),
#    frozenset({'f', 'k', 'p'}),
#    frozenset({'f', 'k', 'o'}),
#    frozenset({'f', 'g', 'k'}),
#    frozenset({'e', 'k', 'y'}),
#    frozenset({'e', 'k', 'p'}),
#    frozenset({'e', 'k', 'o'}),
#    frozenset({'c', 'k', 'y'}),
#    frozenset({'c', 'k', 'p'}),
#    frozenset({'c', 'k', 'o'}),
#    frozenset({'c', 'f', 'k'}),
#    frozenset({'b', 'k', 'y'}),
#    frozenset({'b', 'k', 'p'}),
#    frozenset({'b', 'k', 'o'}),
#    frozenset({'b', 'g', 'k'}),
#    frozenset({'b', 'f', 'k'}),
#    frozenset({'b', 'c', 'k'}),
#    frozenset({'f', 'g', 'o'}),
#    frozenset({'e', 'g', 'p'}),
#    frozenset({'e', 'g', 'o'}),
#    frozenset({'e', 'g', 'k'}),
#    frozenset({'c', 'g', 'o'}),
#    frozenset({'b', 'g', 'o'}),
#    frozenset({'e', 'f', 'y'}),
#    frozenset({'e', 'f', 'p'}),
#    frozenset({'e', 'f', 'o'}),
#    frozenset({'e', 'f', 'l'}),
#    frozenset({'e', 'f', 'k'}),
#    frozenset({'e', 'f', 'g'}),
#    frozenset({'d', 'f', 'p'}),
#    frozenset({'d', 'f', 'o'}),
#    frozenset({'c', 'f', 'y'}),
#    frozenset({'c', 'f', 'o'}),
#    frozenset({'c', 'f', 'l'}),
#    frozenset({'c', 'f', 'g'}),
#    frozenset({'b', 'f', 'y'}),
#    frozenset({'b', 'f', 'o'}),
#    frozenset({'b', 'f', 'l'}),
#    frozenset({'b', 'f', 'g'}),
#    frozenset({'d', 'e', 'p'}),
#    frozenset({'d', 'e', 'o'}),
#    frozenset({'d', 'e', 'f'}),
#    frozenset({'c', 'e', 'y'}),
#    frozenset({'c', 'e', 'p'}),
#    frozenset({'c', 'e', 'o'}),
#    frozenset({'c', 'e', 'l'}),
#    frozenset({'c', 'e', 'k'}),
#    frozenset({'c', 'e', 'g'}),
#    frozenset({'c', 'e', 'f'}),
#    frozenset({'c', 'd', 'e'}),
#    frozenset({'b', 'e', 'y'}),
#    frozenset({'b', 'e', 'p'}),
#    frozenset({'b', 'e', 'o'}),
#    frozenset({'b', 'e', 'l'}),
#    frozenset({'b', 'e', 'k'}),
#    frozenset({'b', 'e', 'g'}),
#    frozenset({'b', 'e', 'f'}),
#    frozenset({'b', 'd', 'e'}),
#    frozenset({'b', 'c', 'e'}),
#    frozenset({'c', 'd', 'p'}),
#    frozenset({'c', 'd', 'o'}),
#    frozenset({'c', 'd', 'f'}),
#    frozenset({'b', 'd', 'p'}),
#    frozenset({'b', 'd', 'o'}),
#    frozenset({'b', 'd', 'f'}),
#    frozenset({'b', 'c', 'd'}),
#    frozenset({'b', 'c', 'y'}),
#    frozenset({'b', 'c', 'o'}),
#    frozenset({'b', 'c', 'l'}),
#    frozenset({'b', 'c', 'g'}),
#    frozenset({'b', 'c', 'f'})],
#   [frozenset({'b', 'd', 'e', 's'}),
#    frozenset({'b', 'd', 'f', 's'}),
#    frozenset({'b', 'd', 'n', 's'}),
#    frozenset({'b', 'd', 'o', 's'}),
#    frozenset({'b', 'd', 'p', 's'}),
#    frozenset({'d', 'e', 'f', 's'}),
#    frozenset({'d', 'e', 'n', 's'}),
#    frozenset({'d', 'f', 'n', 's'}),
#    frozenset({'d', 'e', 'o', 's'}),
#    frozenset({'d', 'f', 'o', 's'}),
#    frozenset({'d', 'n', 'o', 's'}),
#    frozenset({'d', 'e', 'p', 's'}),
#    frozenset({'d', 'f', 'p', 's'}),
#    frozenset({'d', 'n', 'p', 's'}),
#    frozenset({'d', 'o', 'p', 's'}),
#    frozenset({'b', 'e', 'g', 's'}),
#    frozenset({'b', 'f', 'g', 's'}),
#    frozenset({'b', 'g', 'n', 's'}),
#    frozenset({'b', 'g', 'o', 's'}),
#    frozenset({'b', 'g', 'p', 's'}),
#    frozenset({'e', 'f', 'g', 's'}),
#    frozenset({'f', 'g', 'n', 's'}),
#    frozenset({'e', 'g', 'n', 's'}),
#    frozenset({'e', 'g', 'o', 's'}),
#    frozenset({'f', 'g', 'o', 's'}),
#    frozenset({'g', 'n', 'o', 's'}),
#    frozenset({'e', 'g', 'p', 's'}),
#    frozenset({'f', 'g', 'p', 's'}),
#    frozenset({'g', 'n', 'p', 's'}),
#    frozenset({'g', 'o', 'p', 's'}),
#    frozenset({'b', 'f', 'g', 't'}),
#    frozenset({'b', 'g', 'o', 't'}),
#    frozenset({'b', 'g', 'p', 't'}),
#    frozenset({'b', 'g', 't', 'w'}),
#    frozenset({'b', 'e', 'g', 't'}),
#    frozenset({'e', 'f', 'g', 't'}),
#    frozenset({'e', 'g', 'n', 't'}),
#    frozenset({'e', 'g', 'o', 't'}),
#    frozenset({'e', 'g', 'p', 't'}),
#    frozenset({'e', 'g', 't', 'w'}),
#    frozenset({'e', 'g', 's', 't'}),
#    frozenset({'f', 'g', 't', 'w'}),
#    frozenset({'b', 'g', 'n', 't'}),
#    frozenset({'f', 'g', 'n', 't'}),
#    frozenset({'g', 'n', 'o', 't'}),
#    frozenset({'g', 'n', 'p', 't'}),
#    frozenset({'g', 'n', 't', 'w'}),
#    frozenset({'g', 'n', 's', 't'}),
#    frozenset({'f', 'g', 'o', 't'}),
#    frozenset({'g', 'o', 't', 'w'}),
#    frozenset({'f', 'g', 'p', 't'}),
#    frozenset({'g', 'o', 'p', 't'}),
#    frozenset({'g', 'p', 't', 'w'}),
#    frozenset({'b', 'g', 's', 't'}),
#    frozenset({'f', 'g', 's', 't'}),
#    frozenset({'g', 'o', 's', 't'}),
#    frozenset({'g', 'p', 's', 't'}),
#    frozenset({'g', 's', 't', 'w'}),
#    frozenset({'b', 'd', 's', 'w'}),
#    frozenset({'d', 'e', 's', 'w'}),
#    frozenset({'d', 'f', 's', 'w'}),
#    frozenset({'d', 'n', 's', 'w'}),
#    frozenset({'d', 'o', 's', 'w'}),
#    frozenset({'d', 'p', 's', 'w'}),
#    frozenset({'b', 'g', 's', 'w'}),
#    frozenset({'e', 'g', 's', 'w'}),
#    frozenset({'f', 'g', 's', 'w'}),
#    frozenset({'g', 'n', 's', 'w'}),
#    frozenset({'g', 'o', 's', 'w'}),
#    frozenset({'g', 'p', 's', 'w'}),
#    frozenset({'b', 'c', 'k', 's'}),
#    frozenset({'b', 'e', 'k', 's'}),
#    frozenset({'c', 'e', 'k', 's'}),
#    frozenset({'b', 'f', 'k', 's'}),
#    frozenset({'c', 'f', 'k', 's'}),
#    frozenset({'e', 'f', 'k', 's'}),
#    frozenset({'b', 'k', 'n', 's'}),
#    frozenset({'c', 'k', 'n', 's'}),
#    frozenset({'e', 'k', 'n', 's'}),
#    frozenset({'f', 'k', 'n', 's'}),
#    frozenset({'b', 'k', 'o', 's'}),
#    frozenset({'c', 'k', 'o', 's'}),
#    frozenset({'e', 'k', 'o', 's'}),
#    frozenset({'f', 'k', 'o', 's'}),
#    frozenset({'k', 'n', 'o', 's'}),
#    frozenset({'b', 'k', 'p', 's'}),
#    frozenset({'c', 'k', 'p', 's'}),
#    frozenset({'e', 'k', 'p', 's'}),
#    frozenset({'f', 'k', 'p', 's'}),
#    frozenset({'k', 'n', 'p', 's'}),
#    frozenset({'k', 'o', 'p', 's'}),
#    frozenset({'b', 'c', 'k', 't'}),
#    frozenset({'b', 'e', 'k', 't'}),
#    frozenset({'c', 'e', 'k', 't'}),
#    frozenset({'e', 'f', 'k', 't'}),
#    frozenset({'e', 'k', 'n', 't'}),
#    frozenset({'e', 'k', 'o', 't'}),
#    frozenset({'e', 'k', 'p', 't'}),
#    frozenset({'e', 'k', 't', 'w'}),
#    frozenset({'e', 'k', 's', 't'}),
#    frozenset({'b', 'f', 'k', 't'}),
#    frozenset({'c', 'f', 'k', 't'}),
#    frozenset({'b', 'k', 'n', 't'}),
#    frozenset({'c', 'k', 'n', 't'}),
#    frozenset({'f', 'k', 'n', 't'}),
#    frozenset({'k', 'n', 'o', 't'}),
#    frozenset({'k', 'n', 'p', 't'}),
#    frozenset({'k', 'n', 't', 'w'}),
#    frozenset({'k', 'n', 's', 't'}),
#    frozenset({'b', 'k', 'o', 't'}),
#    frozenset({'c', 'k', 'o', 't'}),
#    frozenset({'f', 'k', 'o', 't'}),
#    frozenset({'b', 'k', 'p', 't'}),
#    frozenset({'c', 'k', 'p', 't'}),
#    frozenset({'f', 'k', 'p', 't'}),
#    frozenset({'k', 'o', 'p', 't'}),
#    frozenset({'b', 'k', 't', 'w'}),
#    frozenset({'c', 'k', 't', 'w'}),
#    frozenset({'f', 'k', 't', 'w'}),
#    frozenset({'k', 'o', 't', 'w'}),
#    frozenset({'k', 'p', 't', 'w'}),
#    frozenset({'b', 'k', 's', 't'}),
#    frozenset({'c', 'k', 's', 't'}),
#    frozenset({'f', 'k', 's', 't'}),
#    frozenset({'k', 'o', 's', 't'}),
#    frozenset({'k', 'p', 's', 't'}),
#    frozenset({'k', 's', 't', 'w'}),
#    frozenset({'b', 'k', 's', 'w'}),
#    frozenset({'c', 'k', 's', 'w'}),
#    frozenset({'e', 'k', 's', 'w'}),
#    frozenset({'f', 'k', 's', 'w'}),
#    frozenset({'k', 'n', 's', 'w'}),
#    frozenset({'k', 'o', 's', 'w'}),
#    frozenset({'k', 'p', 's', 'w'}),
#    frozenset({'e', 'k', 'v', 'w'}),
#    frozenset({'b', 'c', 'k', 'v'}),
#    frozenset({'b', 'k', 'p', 'v'}),
#    frozenset({'b', 'f', 'k', 'v'}),
#    frozenset({'c', 'f', 'k', 'v'}),
#    frozenset({'f', 'k', 'p', 'v'}),
#    frozenset({'b', 'k', 'o', 'v'}),
#    frozenset({'c', 'k', 'o', 'v'}),
#    frozenset({'f', 'k', 'o', 'v'}),
#    frozenset({'k', 'o', 'p', 'v'}),
#    frozenset({'c', 'k', 'p', 'v'}),
#    frozenset({'b', 'e', 'k', 'v'}),
#    frozenset({'c', 'e', 'k', 'v'}),
#    frozenset({'e', 'f', 'k', 'v'}),
#    frozenset({'e', 'k', 'o', 'v'}),
#    frozenset({'e', 'k', 'p', 'v'}),
#    frozenset({'b', 'k', 'v', 'w'}),
#    frozenset({'c', 'k', 'v', 'w'}),
#    frozenset({'f', 'k', 'v', 'w'}),
#    frozenset({'k', 'o', 'v', 'w'}),
#    frozenset({'k', 'p', 'v', 'w'}),
#    frozenset({'b', 'c', 'e', 's'}),
#    frozenset({'b', 'c', 'f', 's'}),
#    frozenset({'b', 'e', 'f', 's'}),
#    frozenset({'b', 'c', 'n', 's'}),
#    frozenset({'b', 'e', 'n', 's'}),
#    frozenset({'b', 'f', 'n', 's'}),
#    frozenset({'b', 'c', 'o', 's'}),
#    frozenset({'b', 'e', 'o', 's'}),
#    frozenset({'b', 'f', 'o', 's'}),
#    frozenset({'b', 'n', 'o', 's'}),
#    frozenset({'b', 'c', 'p', 's'}),
#    frozenset({'b', 'e', 'p', 's'}),
#    frozenset({'b', 'f', 'p', 's'}),
#    frozenset({'b', 'n', 'p', 's'}),
#    frozenset({'b', 'o', 'p', 's'}),
#    frozenset({'b', 'c', 's', 'y'}),
#    frozenset({'b', 'e', 's', 'y'}),
#    frozenset({'b', 'f', 's', 'y'}),
#    frozenset({'b', 'n', 's', 'y'}),
#    frozenset({'b', 'o', 's', 'y'}),
#    frozenset({'b', 'p', 's', 'y'}),
#    frozenset({'b', 'c', 's', 'v'}),
#    frozenset({'b', 'e', 's', 'v'}),
#    frozenset({'b', 'f', 's', 'v'}),
#    frozenset({'b', 'n', 's', 'v'}),
#    frozenset({'b', 'o', 's', 'v'}),
#    frozenset({'b', 'p', 's', 'v'}),
#    frozenset({'c', 'e', 'f', 's'}),
#    frozenset({'c', 'e', 'n', 's'}),
#    frozenset({'c', 'f', 'n', 's'}),
#    frozenset({'c', 'e', 'o', 's'}),
#    frozenset({'c', 'f', 'o', 's'}),
#    frozenset({'c', 'n', 'o', 's'}),
#    frozenset({'c', 'e', 'p', 's'}),
#    frozenset({'c', 'f', 'p', 's'}),
#    frozenset({'c', 'n', 'p', 's'}),
#    frozenset({'c', 'o', 'p', 's'}),
#    frozenset({'c', 'e', 's', 'y'}),
#    frozenset({'c', 'f', 's', 'y'}),
#    frozenset({'c', 'n', 's', 'y'}),
#    frozenset({'c', 'o', 's', 'y'}),
#    frozenset({'c', 'p', 's', 'y'}),
#    frozenset({'c', 'e', 's', 'v'}),
#    frozenset({'c', 'f', 's', 'v'}),
#    frozenset({'c', 'n', 's', 'v'}),
#    frozenset({'c', 'o', 's', 'v'}),
#    frozenset({'c', 'p', 's', 'v'}),
#    frozenset({'e', 'f', 'n', 's'}),
#    frozenset({'e', 'f', 'o', 's'}),
#    frozenset({'e', 'f', 'p', 's'}),
#    frozenset({'e', 'f', 's', 'y'}),
#    frozenset({'f', 'n', 's', 'y'}),
#    frozenset({'e', 'f', 's', 'v'}),
#    frozenset({'f', 'n', 's', 'v'}),
#    frozenset({'e', 'n', 'o', 's'}),
#    frozenset({'f', 'n', 'o', 's'}),
#    frozenset({'e', 'n', 'p', 's'}),
#    frozenset({'f', 'n', 'p', 's'}),
#    frozenset({'e', 'n', 's', 'y'}),
#    frozenset({'e', 'n', 's', 'v'}),
#    frozenset({'e', 'o', 'p', 's'}),
#    frozenset({'f', 'o', 'p', 's'}),
#    frozenset({'n', 'o', 'p', 's'}),
#    frozenset({'e', 'o', 's', 'y'}),
#    frozenset({'f', 'o', 's', 'y'}),
#    frozenset({'n', 'o', 's', 'y'}),
#    frozenset({'e', 'o', 's', 'v'}),
#    frozenset({'f', 'o', 's', 'v'}),
#    frozenset({'n', 'o', 's', 'v'}),
#    frozenset({'e', 'p', 's', 'y'}),
#    frozenset({'f', 'p', 's', 'y'}),
#    frozenset({'n', 'p', 's', 'y'}),
#    frozenset({'o', 'p', 's', 'y'}),
#    frozenset({'e', 'p', 's', 'v'}),
#    frozenset({'f', 'p', 's', 'v'}),
#    frozenset({'n', 'p', 's', 'v'}),
#    frozenset({'o', 'p', 's', 'v'}),
#    frozenset({'b', 's', 'v', 'w'}),
#    frozenset({'c', 's', 'v', 'w'}),
#    frozenset({'b', 'c', 's', 'w'}),
#    frozenset({'e', 's', 'v', 'w'}),
#    frozenset({'b', 'e', 's', 'w'}),
#    frozenset({'c', 'e', 's', 'w'}),
#    frozenset({'f', 's', 'v', 'w'}),
#    frozenset({'b', 'f', 's', 'w'}),
#    frozenset({'c', 'f', 's', 'w'}),
#    frozenset({'e', 'f', 's', 'w'}),
#    frozenset({'n', 's', 'v', 'w'}),
#    frozenset({'b', 'n', 's', 'w'}),
#    frozenset({'c', 'n', 's', 'w'}),
#    frozenset({'e', 'n', 's', 'w'}),
#    frozenset({'f', 'n', 's', 'w'}),
#    frozenset({'o', 's', 'v', 'w'}),
#    frozenset({'b', 'o', 's', 'w'}),
#    frozenset({'c', 'o', 's', 'w'}),
#    frozenset({'e', 'o', 's', 'w'}),
#    frozenset({'f', 'o', 's', 'w'}),
#    frozenset({'n', 'o', 's', 'w'}),
#    frozenset({'p', 's', 'v', 'w'}),
#    frozenset({'b', 'p', 's', 'w'}),
#    frozenset({'c', 'p', 's', 'w'}),
#    frozenset({'e', 'p', 's', 'w'}),
#    frozenset({'f', 'p', 's', 'w'}),
#    frozenset({'n', 'p', 's', 'w'}),
#    frozenset({'o', 'p', 's', 'w'}),
#    frozenset({'b', 's', 'w', 'y'}),
#    frozenset({'c', 's', 'w', 'y'}),
#    frozenset({'e', 's', 'w', 'y'}),
#    frozenset({'f', 's', 'w', 'y'}),
#    frozenset({'n', 's', 'w', 'y'}),
#    frozenset({'o', 's', 'w', 'y'}),
#    frozenset({'p', 's', 'w', 'y'}),
#    frozenset({'b', 's', 't', 'x'}),
#    frozenset({'e', 's', 't', 'x'}),
#    frozenset({'b', 'e', 's', 'x'}),
#    frozenset({'f', 's', 't', 'x'}),
#    frozenset({'b', 'f', 's', 'x'}),
#    frozenset({'c', 'f', 's', 'x'}),
#    frozenset({'e', 'f', 's', 'x'}),
#    frozenset({'n', 's', 't', 'x'}),
#    frozenset({'b', 'n', 's', 'x'}),
#    frozenset({'e', 'n', 's', 'x'}),
#    frozenset({'f', 'n', 's', 'x'}),
#    frozenset({'o', 's', 't', 'x'}),
#    frozenset({'b', 'o', 's', 'x'}),
#    frozenset({'e', 'o', 's', 'x'}),
#    frozenset({'f', 'o', 's', 'x'}),
#    frozenset({'n', 'o', 's', 'x'}),
#    frozenset({'p', 's', 't', 'x'}),
#    frozenset({'b', 'p', 's', 'x'}),
#    frozenset({'c', 'p', 's', 'x'}),
#    frozenset({'e', 'p', 's', 'x'}),
#    frozenset({'f', 'p', 's', 'x'}),
#    frozenset({'n', 'p', 's', 'x'}),
#    frozenset({'o', 'p', 's', 'x'}),
#    frozenset({'s', 't', 'w', 'x'}),
#    frozenset({'b', 's', 'w', 'x'}),
#    frozenset({'e', 's', 'w', 'x'}),
#    frozenset({'f', 's', 'w', 'x'}),
#    frozenset({'n', 's', 'w', 'x'}),
#    frozenset({'o', 's', 'w', 'x'}),
#    frozenset({'p', 's', 'w', 'x'}),
#    frozenset({'b', 'c', 'f', 't'}),
#    frozenset({'b', 'c', 'o', 't'}),
#    frozenset({'b', 'f', 'o', 't'}),
#    frozenset({'b', 'c', 'p', 't'}),
#    frozenset({'b', 'f', 'p', 't'}),
#    frozenset({'b', 'o', 'p', 't'}),
#    frozenset({'b', 'c', 't', 'w'}),
#    frozenset({'b', 'f', 't', 'w'}),
#    frozenset({'b', 'o', 't', 'w'}),
#    frozenset({'b', 'p', 't', 'w'}),
#    frozenset({'b', 'c', 't', 'y'}),
#    frozenset({'b', 'f', 't', 'y'}),
#    frozenset({'b', 'o', 't', 'y'}),
#    frozenset({'b', 'p', 't', 'y'}),
#    frozenset({'b', 't', 'w', 'y'}),
#    frozenset({'b', 'c', 't', 'v'}),
#    frozenset({'b', 'f', 't', 'v'}),
#    frozenset({'b', 'o', 't', 'v'}),
#    frozenset({'b', 'p', 't', 'v'}),
#    frozenset({'b', 't', 'v', 'w'}),
#    frozenset({'b', 'c', 'e', 't'}),
#    frozenset({'b', 'c', 'n', 't'}),
#    frozenset({'c', 'f', 'o', 't'}),
#    frozenset({'c', 'f', 'p', 't'}),
#    frozenset({'c', 'o', 'p', 't'}),
#    frozenset({'c', 'f', 't', 'w'}),
#    frozenset({'c', 'o', 't', 'w'}),
#    frozenset({'c', 'p', 't', 'w'}),
#    frozenset({'c', 'f', 't', 'y'}),
#    frozenset({'c', 'o', 't', 'y'}),
#    frozenset({'c', 'p', 't', 'y'}),
#    frozenset({'c', 't', 'w', 'y'}),
#    frozenset({'b', 'c', 's', 't'}),
#    frozenset({'c', 'f', 't', 'v'}),
#    frozenset({'c', 'o', 't', 'v'}),
#    frozenset({'c', 'p', 't', 'v'}),
#    frozenset({'c', 't', 'v', 'w'}),
#    frozenset({'b', 'e', 'f', 't'}),
#    frozenset({'c', 'e', 'f', 't'}),
#    frozenset({'b', 'e', 'n', 't'}),
#    frozenset({'c', 'e', 'n', 't'}),
#    frozenset({'e', 'f', 'n', 't'}),
#    frozenset({'b', 'e', 'o', 't'}),
#    frozenset({'c', 'e', 'o', 't'}),
#    frozenset({'e', 'f', 'o', 't'}),
#    frozenset({'e', 'n', 'o', 't'}),
#    frozenset({'b', 'e', 'p', 't'}),
#    frozenset({'c', 'e', 'p', 't'}),
#    frozenset({'e', 'f', 'p', 't'}),
#    frozenset({'e', 'n', 'p', 't'}),
#    frozenset({'e', 'o', 'p', 't'}),
#    frozenset({'b', 'e', 't', 'w'}),
#    frozenset({'c', 'e', 't', 'w'}),
#    frozenset({'e', 'f', 't', 'w'}),
#    frozenset({'e', 'n', 't', 'w'}),
#    frozenset({'e', 'o', 't', 'w'}),
#    frozenset({'e', 'p', 't', 'w'}),
#    frozenset({'b', 'e', 't', 'y'}),
#    frozenset({'c', 'e', 't', 'y'}),
#    frozenset({'e', 'f', 't', 'y'}),
#    frozenset({'e', 'n', 't', 'y'}),
#    frozenset({'e', 'o', 't', 'y'}),
#    frozenset({'e', 'p', 't', 'y'}),
#    frozenset({'e', 't', 'w', 'y'}),
#    frozenset({'b', 'e', 's', 't'}),
#    frozenset({'c', 'e', 's', 't'}),
#    frozenset({'e', 'f', 's', 't'}),
#    frozenset({'e', 'n', 's', 't'}),
#    frozenset({'e', 'o', 's', 't'}),
#    frozenset({'e', 'p', 's', 't'}),
#    frozenset({'e', 's', 't', 'w'}),
#    frozenset({'e', 's', 't', 'y'}),
#    frozenset({'b', 'e', 't', 'v'}),
#    frozenset({'c', 'e', 't', 'v'}),
#    frozenset({'e', 'f', 't', 'v'}),
#    frozenset({'e', 'n', 't', 'v'}),
#    frozenset({'e', 'o', 't', 'v'}),
#    frozenset({'e', 'p', 't', 'v'}),
#    frozenset({'e', 't', 'v', 'w'}),
#    frozenset({'e', 's', 't', 'v'}),
#    frozenset({'b', 'f', 'n', 't'}),
#    frozenset({'c', 'f', 'n', 't'}),
#    frozenset({'f', 't', 'w', 'y'}),
#    frozenset({'b', 'f', 's', 't'}),
#    frozenset({'c', 'f', 's', 't'}),
#    frozenset({'f', 't', 'v', 'w'}),
#    frozenset({'b', 'n', 'o', 't'}),
#    frozenset({'c', 'n', 'o', 't'}),
#    frozenset({'f', 'n', 'o', 't'}),
#    frozenset({'b', 'n', 'p', 't'}),
#    frozenset({'c', 'n', 'p', 't'}),
#    frozenset({'f', 'n', 'p', 't'}),
#    frozenset({'n', 'o', 'p', 't'}),
#    frozenset({'b', 'n', 't', 'w'}),
#    frozenset({'c', 'n', 't', 'w'}),
#    frozenset({'f', 'n', 't', 'w'}),
#    frozenset({'n', 'o', 't', 'w'}),
#    frozenset({'n', 'p', 't', 'w'}),
#    frozenset({'b', 'n', 't', 'y'}),
#    frozenset({'c', 'n', 't', 'y'}),
#    frozenset({'f', 'n', 't', 'y'}),
#    frozenset({'n', 'o', 't', 'y'}),
#    frozenset({'n', 'p', 't', 'y'}),
#    frozenset({'n', 't', 'w', 'y'}),
#    frozenset({'b', 'n', 's', 't'}),
#    frozenset({'c', 'n', 's', 't'}),
#    frozenset({'f', 'n', 's', 't'}),
#    frozenset({'n', 'o', 's', 't'}),
#    frozenset({'n', 'p', 's', 't'}),
#    frozenset({'n', 's', 't', 'w'}),
#    frozenset({'n', 's', 't', 'y'}),
#    frozenset({'b', 'n', 't', 'v'}),
#    frozenset({'c', 'n', 't', 'v'}),
#    frozenset({'f', 'n', 't', 'v'}),
#    frozenset({'n', 'o', 't', 'v'}),
#    frozenset({'n', 'p', 't', 'v'}),
#    frozenset({'n', 't', 'v', 'w'}),
#    frozenset({'n', 's', 't', 'v'}),
#    frozenset({'f', 'o', 'p', 't'}),
#    frozenset({'f', 'o', 't', 'w'}),
#    frozenset({'f', 'o', 't', 'y'}),
#    frozenset({'o', 't', 'w', 'y'}),
#    frozenset({'b', 'o', 's', 't'}),
#    frozenset({'c', 'o', 's', 't'}),
#    frozenset({'f', 'o', 's', 't'}),
#    frozenset({'f', 'o', 't', 'v'}),
#    frozenset({'o', 't', 'v', 'w'}),
#    frozenset({'f', 'p', 't', 'w'}),
#    frozenset({'o', 'p', 't', 'w'}),
#    frozenset({'f', 'p', 't', 'y'}),
#    frozenset({'o', 'p', 't', 'y'}),
#    frozenset({'p', 't', 'w', 'y'}),
#    frozenset({'b', 'p', 's', 't'}),
#    frozenset({'c', 'p', 's', 't'}),
#    frozenset({'f', 'p', 's', 't'}),
#    frozenset({'o', 'p', 's', 't'}),
#    frozenset({'f', 'p', 't', 'v'}),
#    frozenset({'o', 'p', 't', 'v'}),
#    frozenset({'p', 't', 'v', 'w'}),
#    frozenset({'b', 's', 't', 'w'}),
#    frozenset({'c', 's', 't', 'w'}),
#    frozenset({'f', 's', 't', 'w'}),
#    frozenset({'o', 's', 't', 'w'}),
#    frozenset({'p', 's', 't', 'w'}),
#    frozenset({'b', 'e', 't', 'x'}),
#    frozenset({'b', 'f', 't', 'x'}),
#    frozenset({'e', 'f', 't', 'x'}),
#    frozenset({'b', 'n', 't', 'x'}),
#    frozenset({'e', 'n', 't', 'x'}),
#    frozenset({'f', 'n', 't', 'x'}),
#    frozenset({'b', 'o', 't', 'x'}),
#    frozenset({'e', 'o', 't', 'x'}),
#    frozenset({'f', 'o', 't', 'x'}),
#    frozenset({'b', 'p', 't', 'x'}),
#    frozenset({'e', 'p', 't', 'x'}),
#    frozenset({'f', 'p', 't', 'x'}),
#    frozenset({'n', 'p', 't', 'x'}),
#    frozenset({'o', 'p', 't', 'x'}),
#    frozenset({'b', 't', 'w', 'x'}),
#    frozenset({'e', 't', 'w', 'x'}),
#    frozenset({'f', 't', 'w', 'x'}),
#    frozenset({'n', 't', 'w', 'x'}),
#    frozenset({'o', 't', 'w', 'x'}),
#    frozenset({'p', 't', 'w', 'x'}),
#    frozenset({'b', 's', 't', 'y'}),
#    frozenset({'c', 's', 't', 'y'}),
#    frozenset({'f', 's', 't', 'y'}),
#    frozenset({'o', 's', 't', 'y'}),
#    frozenset({'p', 's', 't', 'y'}),
#    frozenset({'s', 't', 'w', 'y'}),
#    frozenset({'b', 's', 't', 'v'}),
#    frozenset({'c', 's', 't', 'v'}),
#    frozenset({'f', 's', 't', 'v'}),
#    frozenset({'o', 's', 't', 'v'}),
#    frozenset({'p', 's', 't', 'v'}),
#    frozenset({'s', 't', 'v', 'w'}),
#    frozenset({'b', 'f', 'o', 'v'}),
#    frozenset({'b', 'c', 'f', 'v'}),
#    frozenset({'b', 'c', 'o', 'v'}),
#    frozenset({'c', 'f', 'o', 'v'}),
#    frozenset({'b', 'c', 'e', 'v'}),
#    frozenset({'b', 'e', 'f', 'v'}),
#    frozenset({'b', 'e', 'o', 'v'}),
#    frozenset({'b', 'e', 'p', 'v'}),
#    frozenset({'c', 'e', 'f', 'v'}),
#    frozenset({'c', 'e', 'o', 'v'}),
#    frozenset({'c', 'e', 'p', 'v'}),
#    frozenset({'e', 'f', 'o', 'v'}),
#    frozenset({'e', 'f', 'p', 'v'}),
#    frozenset({'e', 'o', 'p', 'v'}),
#    frozenset({'b', 'c', 'n', 'v'}),
#    frozenset({'b', 'e', 'n', 'v'}),
#    frozenset({'b', 'f', 'n', 'v'}),
#    frozenset({'b', 'n', 'o', 'v'}),
#    frozenset({'b', 'n', 'p', 'v'}),
#    frozenset({'c', 'e', 'n', 'v'}),
#    frozenset({'c', 'f', 'n', 'v'}),
#    frozenset({'c', 'n', 'o', 'v'}),
#    frozenset({'c', 'n', 'p', 'v'}),
#    frozenset({'e', 'f', 'n', 'v'}),
#    frozenset({'e', 'n', 'o', 'v'}),
#    frozenset({'f', 'n', 'o', 'v'}),
#    frozenset({'e', 'n', 'p', 'v'}),
#    frozenset({'f', 'n', 'p', 'v'}),
#    frozenset({'n', 'o', 'p', 'v'}),
#    frozenset({'b', 'c', 'p', 'v'}),
#    frozenset({'b', 'f', 'p', 'v'}),
#    frozenset({'c', 'f', 'p', 'v'}),
#    frozenset({'b', 'o', 'p', 'v'}),
#    frozenset({'c', 'o', 'p', 'v'}),
#    frozenset({'f', 'o', 'p', 'v'}),
#    frozenset({'b', 'c', 'v', 'w'}),
#    frozenset({'b', 'f', 'v', 'w'}),
#    frozenset({'b', 'o', 'v', 'w'}),
#    frozenset({'b', 'p', 'v', 'w'}),
#    frozenset({'c', 'f', 'v', 'w'}),
#    frozenset({'c', 'o', 'v', 'w'}),
#    frozenset({'c', 'p', 'v', 'w'}),
#    frozenset({'b', 'e', 'v', 'w'}),
#    frozenset({'c', 'e', 'v', 'w'}),
#    frozenset({'e', 'f', 'v', 'w'}),
#    frozenset({'e', 'n', 'v', 'w'}),
#    frozenset({'e', 'o', 'v', 'w'}),
#    frozenset({'e', 'p', 'v', 'w'}),
#    frozenset({'b', 'n', 'v', 'w'}),
#    frozenset({'c', 'n', 'v', 'w'}),
#    frozenset({'f', 'n', 'v', 'w'}),
#    frozenset({'n', 'o', 'v', 'w'}),
#    frozenset({'n', 'p', 'v', 'w'}),
#    frozenset({'f', 'o', 'v', 'w'}),
#    frozenset({'f', 'p', 'v', 'w'}),
#    frozenset({'o', 'p', 'v', 'w'}),
#    frozenset({'b', 'c', 'd', 'f'}),
#    frozenset({'b', 'c', 'd', 'o'}),
#    frozenset({'b', 'd', 'f', 'o'}),
#    frozenset({'b', 'c', 'd', 'p'}),
#    frozenset({'b', 'd', 'f', 'p'}),
#    frozenset({'b', 'd', 'o', 'p'}),
#    frozenset({'c', 'd', 'f', 'o'}),
#    frozenset({'c', 'd', 'f', 'p'}),
#    frozenset({'c', 'd', 'o', 'p'}),
#    frozenset({'b', 'c', 'd', 'e'}),
#    frozenset({'b', 'c', 'e', 'f'}),
#    frozenset({'b', 'd', 'e', 'f'}),
#    frozenset({'b', 'c', 'e', 'g'}),
#    frozenset({'b', 'e', 'f', 'g'}),
#    frozenset({'b', 'c', 'e', 'l'}),
#    frozenset({'b', 'e', 'f', 'l'}),
#    frozenset({'b', 'c', 'e', 'o'}),
#    frozenset({'b', 'd', 'e', 'o'}),
#    frozenset({'b', 'e', 'f', 'o'}),
#    frozenset({'b', 'e', 'g', 'o'}),
#    frozenset({'b', 'e', 'l', 'o'}),
#    frozenset({'b', 'c', 'e', 'p'}),
#    frozenset({'b', 'd', 'e', 'p'}),
#    frozenset({'b', 'e', 'f', 'p'}),
#    frozenset({'b', 'e', 'g', 'p'}),
#    frozenset({'b', 'e', 'l', 'p'}),
#    frozenset({'b', 'e', 'o', 'p'}),
#    frozenset({'b', 'c', 'e', 'y'}),
#    frozenset({'b', 'e', 'f', 'y'}),
#    frozenset({'b', 'e', 'o', 'y'}),
#    frozenset({'b', 'e', 'p', 'y'}),
#    frozenset({'c', 'd', 'e', 'f'}),
#    frozenset({'c', 'e', 'f', 'g'}),
#    frozenset({'b', 'c', 'e', 'k'}),
#    frozenset({'c', 'e', 'f', 'l'}),
#    frozenset({'c', 'd', 'e', 'o'}),
#    frozenset({'c', 'e', 'f', 'o'}),
#    frozenset({'c', 'e', 'g', 'o'}),
#    frozenset({'c', 'e', 'l', 'o'}),
#    frozenset({'c', 'd', 'e', 'p'}),
#    frozenset({'c', 'e', 'f', 'p'}),
#    frozenset({'c', 'e', 'g', 'p'}),
#    frozenset({'c', 'e', 'l', 'p'}),
#    frozenset({'c', 'e', 'o', 'p'}),
#    frozenset({'c', 'e', 'f', 'y'}),
#    frozenset({'c', 'e', 'o', 'y'}),
#    frozenset({'c', 'e', 'p', 'y'}),
#    frozenset({'b', 'c', 'f', 'g'}),
#    frozenset({'b', 'c', 'f', 'l'}),
#    frozenset({'b', 'c', 'f', 'o'}),
#    frozenset({'b', 'c', 'f', 'y'}),
#    frozenset({'b', 'e', 'f', 'k'}),
#    frozenset({'c', 'e', 'f', 'k'}),
#    frozenset({'d', 'e', 'f', 'o'}),
#    frozenset({'d', 'e', 'f', 'p'}),
#    frozenset({'b', 'f', 'g', 'o'}),
#    frozenset({'b', 'c', 'g', 'o'}),
#    frozenset({'c', 'f', 'g', 'o'}),
#    frozenset({'b', 'e', 'g', 'k'}),
#    frozenset({'e', 'f', 'g', 'k'}),
#    frozenset({'e', 'f', 'g', 'o'}),
#    frozenset({'e', 'f', 'g', 'p'}),
#    frozenset({'b', 'c', 'k', 'p'}),
#    frozenset({'b', 'g', 'k', 'p'}),
#    frozenset({'b', 'c', 'k', 'y'}),
#    frozenset({'b', 'k', 'p', 'y'}),
#    frozenset({'b', 'c', 'f', 'k'}),
#    frozenset({'b', 'c', 'k', 'o'}),
#    frozenset({'b', 'e', 'k', 'o'}),
#    frozenset({'c', 'e', 'k', 'o'}),
#    frozenset({'e', 'f', 'k', 'o'}),
#    frozenset({'e', 'g', 'k', 'o'}),
#    frozenset({'b', 'e', 'k', 'p'}),
#    frozenset({'c', 'e', 'k', 'p'}),
#    frozenset({'e', 'f', 'k', 'p'}),
#    frozenset({'e', 'g', 'k', 'p'}),
#    frozenset({'e', 'k', 'o', 'p'}),
#    frozenset({'b', 'e', 'k', 'y'}),
#    frozenset({'c', 'e', 'k', 'y'}),
#    frozenset({'e', 'f', 'k', 'y'}),
#    frozenset({'e', 'k', 'o', 'y'}),
#    frozenset({'e', 'k', 'p', 'y'}),
#    frozenset({'b', 'f', 'g', 'k'}),
#    frozenset({'b', 'f', 'k', 'o'}),
#    frozenset({'c', 'f', 'k', 'o'}),
#    frozenset({'b', 'f', 'k', 'p'}),
#    frozenset({'c', 'f', 'k', 'p'}),
#    frozenset({'f', 'g', 'k', 'p'}),
#    frozenset({'b', 'f', 'k', 'y'}),
#    frozenset({'c', 'f', 'k', 'y'}),
#    frozenset({'f', 'k', 'p', 'y'}),
#    frozenset({'b', 'g', 'k', 'o'}),
#    frozenset({'f', 'g', 'k', 'o'}),
#    frozenset({'b', 'f', 'l', 'o'}),
#    frozenset({'b', 'c', 'l', 'o'}),
#    frozenset({'c', 'f', 'l', 'o'}),
#    frozenset({'e', 'f', 'l', 'o'}),
#    frozenset({'e', 'f', 'l', 'p'}),
#    frozenset({'b', 'c', 'd', 'n'}),
#    frozenset({'b', 'c', 'e', 'n'}),
#    frozenset({'b', 'd', 'e', 'n'}),
#    frozenset({'b', 'c', 'f', 'n'}),
#    frozenset({'b', 'd', 'f', 'n'}),
#    frozenset({'b', 'e', 'f', 'n'}),
#    frozenset({'b', 'e', 'g', 'n'}),
#    frozenset({'b', 'f', 'g', 'n'}),
#    frozenset({'b', 'c', 'n', 'o'}),
#    frozenset({'b', 'd', 'n', 'o'}),
#    frozenset({'b', 'e', 'n', 'o'}),
#    frozenset({'b', 'f', 'n', 'o'}),
#    frozenset({'b', 'g', 'n', 'o'}),
#    frozenset({'b', 'c', 'n', 'p'}),
#    frozenset({'b', 'd', 'n', 'p'}),
#    frozenset({'b', 'e', 'n', 'p'}),
#    frozenset({'b', 'f', 'n', 'p'}),
#    frozenset({'b', 'g', 'n', 'p'}),
#    frozenset({'b', 'n', 'o', 'p'}),
#    frozenset({'b', 'c', 'n', 'y'}),
#    frozenset({'b', 'e', 'n', 'y'}),
#    frozenset({'b', 'f', 'n', 'y'}),
#    frozenset({'b', 'n', 'o', 'y'}),
#    frozenset({'b', 'n', 'p', 'y'}),
#    frozenset({'c', 'd', 'e', 'n'}),
#    frozenset({'c', 'd', 'f', 'n'}),
#    frozenset({'c', 'e', 'f', 'n'}),
#    frozenset({'c', 'e', 'g', 'n'}),
#    frozenset({'c', 'f', 'g', 'n'}),
#    frozenset({'b', 'c', 'k', 'n'}),
#    frozenset({'c', 'd', 'n', 'o'}),
#    frozenset({'c', 'e', 'n', 'o'}),
#    frozenset({'c', 'f', 'n', 'o'}),
#    frozenset({'c', 'd', 'n', 'p'}),
#    frozenset({'c', 'e', 'n', 'p'}),
#    frozenset({'c', 'f', 'n', 'p'}),
#    frozenset({'c', 'g', 'n', 'p'}),
#    frozenset({'c', 'n', 'o', 'p'}),
#    frozenset({'c', 'e', 'n', 'y'}),
#    frozenset({'c', 'f', 'n', 'y'}),
#    frozenset({'c', 'n', 'o', 'y'}),
#    frozenset({'c', 'n', 'p', 'y'}),
#    frozenset({'d', 'e', 'f', 'n'}),
#    frozenset({'b', 'e', 'k', 'n'}),
#    frozenset({'c', 'e', 'k', 'n'}),
#    frozenset({'d', 'e', 'n', 'o'}),
#    frozenset({'d', 'e', 'n', 'p'}),
#    frozenset({'e', 'f', 'g', 'n'}),
#    frozenset({'b', 'f', 'k', 'n'}),
#    frozenset({'c', 'f', 'k', 'n'}),
#    frozenset({'e', 'f', 'k', 'n'}),
#    frozenset({'d', 'f', 'n', 'o'}),
#    frozenset({'e', 'f', 'n', 'o'}),
#    frozenset({'d', 'f', 'n', 'p'}),
#    frozenset({'e', 'f', 'n', 'p'}),
#    frozenset({'e', 'f', 'n', 'y'}),
#    frozenset({'e', 'g', 'n', 'o'}),
#    frozenset({'f', 'g', 'n', 'o'}),
#    frozenset({'e', 'g', 'n', 'p'}),
#    frozenset({'f', 'g', 'n', 'p'}),
#    frozenset({'b', 'k', 'n', 'o'}),
#    frozenset({'c', 'k', 'n', 'o'}),
#    frozenset({'e', 'k', 'n', 'o'}),
#    frozenset({'f', 'k', 'n', 'o'}),
#    frozenset({'b', 'k', 'n', 'p'}),
#    frozenset({'c', 'k', 'n', 'p'}),
#    frozenset({'e', 'k', 'n', 'p'}),
#    frozenset({'f', 'k', 'n', 'p'}),
#    frozenset({'k', 'n', 'o', 'p'}),
#    frozenset({'b', 'k', 'n', 'y'}),
#    frozenset({'c', 'k', 'n', 'y'}),
#    frozenset({'e', 'k', 'n', 'y'}),
#    frozenset({'f', 'k', 'n', 'y'}),
#    frozenset({'k', 'n', 'o', 'y'}),
#    frozenset({'k', 'n', 'p', 'y'}),
#    frozenset({'b', 'f', 'o', 'y'}),
#    frozenset({'b', 'c', 'o', 'y'}),
#    frozenset({'c', 'f', 'o', 'y'}),
#    frozenset({'d', 'f', 'o', 'p'}),
#    frozenset({'d', 'e', 'o', 'p'}),
#    frozenset({'e', 'f', 'o', 'p'}),
#    frozenset({'e', 'g', 'o', 'p'}),
#    frozenset({'e', 'l', 'o', 'p'}),
#    frozenset({'e', 'f', 'o', 'y'}),
#    frozenset({'b', 'k', 'o', 'p'}),
#    frozenset({'c', 'k', 'o', 'p'}),
#    frozenset({'f', 'k', 'o', 'p'}),
#    frozenset({'g', 'k', 'o', 'p'}),
#    frozenset({'b', 'k', 'o', 'y'}),
#    frozenset({'c', 'k', 'o', 'y'}),
#    frozenset({'f', 'k', 'o', 'y'}),
#    frozenset({'k', 'o', 'p', 'y'}),
#    frozenset({'d', 'n', 'o', 'p'}),
#    frozenset({'e', 'n', 'o', 'p'}),
#    frozenset({'f', 'n', 'o', 'p'}),
#    frozenset({'g', 'n', 'o', 'p'}),
#    frozenset({'e', 'n', 'o', 'y'}),
#    frozenset({'f', 'n', 'o', 'y'}),
#    frozenset({'b', 'c', 'g', 'p'}),
#    frozenset({'b', 'c', 'p', 'y'}),
#    frozenset({'b', 'c', 'f', 'p'}),
#    frozenset({'b', 'c', 'l', 'p'}),
#    frozenset({'b', 'c', 'o', 'p'}),
#    frozenset({'e', 'f', 'p', 'y'}),
#    frozenset({'e', 'o', 'p', 'y'}),
#    frozenset({'b', 'f', 'g', 'p'}),
#    frozenset({'c', 'f', 'g', 'p'}),
#    frozenset({'b', 'f', 'l', 'p'}),
#    frozenset({'c', 'f', 'l', 'p'}),
#    frozenset({'b', 'f', 'o', 'p'}),
#    frozenset({'c', 'f', 'o', 'p'}),
#    frozenset({'b', 'f', 'p', 'y'}),
#    frozenset({'c', 'f', 'p', 'y'}),
#    frozenset({'b', 'g', 'o', 'p'}),
#    frozenset({'c', 'g', 'o', 'p'}),
#    frozenset({'f', 'g', 'o', 'p'}),
#    frozenset({'c', 'k', 'p', 'y'}),
#    frozenset({'b', 'l', 'o', 'p'}),
#    frozenset({'c', 'l', 'o', 'p'}),
#    frozenset({'f', 'l', 'o', 'p'}),
#    frozenset({'e', 'n', 'p', 'y'}),
#    frozenset({'f', 'n', 'p', 'y'}),
#    frozenset({'n', 'o', 'p', 'y'}),
#    frozenset({'b', 'o', 'p', 'y'}),
#    frozenset({'c', 'o', 'p', 'y'}),
#    frozenset({'f', 'o', 'p', 'y'}),
#    frozenset({'b', 'c', 'f', 'w'}),
#    frozenset({'b', 'c', 'g', 'w'}),
#    frozenset({'b', 'f', 'g', 'w'}),
#    frozenset({'b', 'f', 'l', 'w'}),
#    frozenset({'b', 'c', 'o', 'w'}),
#    frozenset({'b', 'f', 'o', 'w'}),
#    frozenset({'b', 'g', 'o', 'w'}),
#    frozenset({'b', 'l', 'o', 'w'}),
#    frozenset({'b', 'c', 'p', 'w'}),
#    frozenset({'b', 'f', 'p', 'w'}),
#    frozenset({'b', 'g', 'p', 'w'}),
#    frozenset({'b', 'l', 'p', 'w'}),
#    frozenset({'b', 'o', 'p', 'w'}),
#    frozenset({'b', 'c', 'w', 'y'}),
#    frozenset({'b', 'f', 'w', 'y'}),
#    frozenset({'b', 'o', 'w', 'y'}),
#    frozenset({'b', 'p', 'w', 'y'}),
#    frozenset({'b', 'c', 'd', 'w'}),
#    frozenset({'b', 'c', 'e', 'w'}),
#    frozenset({'c', 'f', 'g', 'w'}),
#    frozenset({'b', 'c', 'k', 'w'}),
#    frozenset({'b', 'c', 'n', 'w'}),
#    frozenset({'c', 'f', 'o', 'w'}),
#    frozenset({'c', 'g', 'o', 'w'}),
#    frozenset({'c', 'f', 'p', 'w'}),
#    frozenset({'c', 'g', 'p', 'w'}),
#    frozenset({'c', 'o', 'p', 'w'}),
#    frozenset({'c', 'f', 'w', 'y'}),
#    frozenset({'c', 'o', 'w', 'y'}),
#    frozenset({'c', 'p', 'w', 'y'}),
#    frozenset({'b', 'd', 'e', 'w'}),
#    frozenset({'c', 'd', 'e', 'w'}),
#    frozenset({'b', 'd', 'f', 'w'}),
#    frozenset({'c', 'd', 'f', 'w'}),
#    frozenset({'d', 'e', 'f', 'w'}),
#    frozenset({'b', 'd', 'n', 'w'}),
#    frozenset({'c', 'd', 'n', 'w'}),
#    frozenset({'d', 'e', 'n', 'w'}),
#    frozenset({'d', 'f', 'n', 'w'}),
#    frozenset({'b', 'd', 'o', 'w'}),
#    frozenset({'c', 'd', 'o', 'w'}),
#    frozenset({'d', 'e', 'o', 'w'}),
#    frozenset({'d', 'f', 'o', 'w'}),
#    frozenset({'d', 'n', 'o', 'w'}),
#    frozenset({'b', 'd', 'p', 'w'}),
#    frozenset({'c', 'd', 'p', 'w'}),
#    frozenset({'d', 'e', 'p', 'w'}),
#    frozenset({'d', 'f', 'p', 'w'}),
#    frozenset({'d', 'n', 'p', 'w'}),
#    frozenset({'d', 'o', 'p', 'w'}),
#    frozenset({'b', 'e', 'f', 'w'}),
#    frozenset({'c', 'e', 'f', 'w'}),
#    frozenset({'b', 'e', 'g', 'w'}),
#    frozenset({'c', 'e', 'g', 'w'}),
#    frozenset({'e', 'f', 'g', 'w'}),
#    frozenset({'b', 'e', 'k', 'w'}),
#    frozenset({'c', 'e', 'k', 'w'}),
#    frozenset({'e', 'f', 'k', 'w'}),
#    frozenset({'e', 'g', 'k', 'w'}),
#    frozenset({'b', 'e', 'l', 'w'}),
#    frozenset({'e', 'f', 'l', 'w'}),
#    frozenset({'b', 'e', 'n', 'w'}),
#    frozenset({'c', 'e', 'n', 'w'}),
#    frozenset({'e', 'f', 'n', 'w'}),
#    frozenset({'e', 'g', 'n', 'w'}),
#    frozenset({'e', 'k', 'n', 'w'}),
#    frozenset({'b', 'e', 'o', 'w'}),
#    frozenset({'c', 'e', 'o', 'w'}),
#    frozenset({'e', 'f', 'o', 'w'}),
#    frozenset({'e', 'g', 'o', 'w'}),
#    frozenset({'e', 'k', 'o', 'w'}),
#    frozenset({'e', 'l', 'o', 'w'}),
#    frozenset({'e', 'n', 'o', 'w'}),
#    frozenset({'b', 'e', 'p', 'w'}),
#    frozenset({'c', 'e', 'p', 'w'}),
#    frozenset({'e', 'f', 'p', 'w'}),
#    frozenset({'e', 'g', 'p', 'w'}),
#    frozenset({'e', 'k', 'p', 'w'}),
#    frozenset({'e', 'l', 'p', 'w'}),
#    frozenset({'e', 'n', 'p', 'w'}),
#    frozenset({'e', 'o', 'p', 'w'}),
#    frozenset({'b', 'e', 'w', 'y'}),
#    frozenset({'c', 'e', 'w', 'y'}),
#    frozenset({'e', 'f', 'w', 'y'}),
#    frozenset({'e', 'k', 'w', 'y'}),
#    frozenset({'e', 'n', 'w', 'y'}),
#    frozenset({'e', 'o', 'w', 'y'}),
#    frozenset({'e', 'p', 'w', 'y'}),
#    frozenset({'b', 'f', 'k', 'w'}),
#    frozenset({'c', 'f', 'k', 'w'}),
#    frozenset({'b', 'f', 'n', 'w'}),
#    frozenset({'c', 'f', 'n', 'w'}),
#    frozenset({'b', 'g', 'k', 'w'}),
#    frozenset({'f', 'g', 'k', 'w'}),
#    frozenset({'b', 'g', 'n', 'w'}),
#    frozenset({'c', 'g', 'n', 'w'}),
#    frozenset({'f', 'g', 'n', 'w'}),
#    frozenset({'f', 'g', 'o', 'w'}),
#    frozenset({'f', 'g', 'p', 'w'}),
#    frozenset({'b', 'k', 'n', 'w'}),
#    frozenset({'c', 'k', 'n', 'w'}),
#    frozenset({'f', 'k', 'n', 'w'}),
#    frozenset({'b', 'k', 'o', 'w'}),
#    frozenset({'c', 'k', 'o', 'w'}),
#    frozenset({'f', 'k', 'o', 'w'}),
#    frozenset({'g', 'k', 'o', 'w'}),
#    frozenset({'b', 'k', 'p', 'w'}),
#    frozenset({'c', 'k', 'p', 'w'}),
#    frozenset({'f', 'k', 'p', 'w'}),
#    frozenset({'g', 'k', 'p', 'w'}),
#    frozenset({'k', 'o', 'p', 'w'}),
#    frozenset({'b', 'k', 'w', 'y'}),
#    frozenset({'c', 'k', 'w', 'y'}),
#    frozenset({'f', 'k', 'w', 'y'}),
#    frozenset({'k', 'o', 'w', 'y'}),
#    frozenset({'k', 'p', 'w', 'y'}),
#    frozenset({'f', 'l', 'o', 'w'}),
#    frozenset({'f', 'l', 'p', 'w'}),
#    frozenset({'b', 'n', 'o', 'w'}),
#    frozenset({'c', 'n', 'o', 'w'}),
#    frozenset({'f', 'n', 'o', 'w'}),
#    frozenset({'g', 'n', 'o', 'w'}),
# ...
#   frozenset({'g', 'p', 'v'}): 0.178,
#   frozenset({'d', 'v', 'w'}): 0.232,
#   frozenset({'g', 'v', 'w'}): 0.178,
#   frozenset({'k', 'v', 'w'}): 0.335,
#   frozenset({'b', 'k', 's'}): 0.444,
#   frozenset({'c', 'k', 's'}): 0.372,
#   frozenset({'e', 'k', 's'}): 0.459,
#   frozenset({'f', 'k', 's'}): 0.459,
#   frozenset({'k', 'n', 's'}): 0.437,
#   frozenset({'k', 'o', 's'}): 0.428,
#   frozenset({'k', 'p', 's'}): 0.459,
#   frozenset({'k', 's', 'y'}): 0.243,
#   frozenset({'k', 's', 'v'}): 0.23,
#   frozenset({'b', 'k', 't'}): 0.455,
#   frozenset({'c', 'k', 't'}): 0.371,
#   frozenset({'e', 'k', 't'}): 0.466,
#   frozenset({'f', 'k', 't'}): 0.466,
#   frozenset({'k', 'n', 't'}): 0.444,
#   frozenset({'k', 'o', 't'}): 0.434,
#   frozenset({'k', 'p', 't'}): 0.466,
#   frozenset({'k', 't', 'w'}): 0.466,
#   frozenset({'k', 't', 'y'}): 0.262,
#   frozenset({'k', 's', 't'}): 0.436,
#   frozenset({'k', 't', 'v'}): 0.239,
#   frozenset({'k', 'v', 'y'}): 0.211,
#   frozenset({'k', 's', 'w'}): 0.459,
#   frozenset({'k', 's', 'x'}): 0.216,
#   frozenset({'k', 't', 'x'}): 0.208,
#   frozenset({'d', 'g', 's'}): 0.172,
#   frozenset({'d', 'k', 's'}): 0.184,
#   frozenset({'b', 'd', 's'}): 0.307,
#   frozenset({'c', 'd', 's'}): 0.297,
#   frozenset({'d', 'e', 's'}): 0.313,
#   frozenset({'d', 'f', 's'}): 0.313,
#   frozenset({'d', 'n', 's'}): 0.313,
#   frozenset({'d', 'o', 's'}): 0.312,
#   frozenset({'d', 'p', 's'}): 0.313,
#   frozenset({'d', 's', 'y'}): 0.205,
#   frozenset({'g', 'k', 's'}): 0.225,
#   frozenset({'b', 'g', 's'}): 0.384,
#   frozenset({'c', 'g', 's'}): 0.279,
#   frozenset({'e', 'g', 's'}): 0.376,
#   frozenset({'f', 'g', 's'}): 0.401,
#   frozenset({'g', 'n', 's'}): 0.364,
#   frozenset({'g', 'o', 's'}): 0.359,
#   frozenset({'g', 'p', 's'}): 0.401,
#   frozenset({'g', 's', 'y'}): 0.177,
#   frozenset({'g', 'k', 't'}): 0.221,
#   frozenset({'b', 'g', 't'}): 0.38,
#   frozenset({'c', 'g', 't'}): 0.257,
#   frozenset({'e', 'g', 't'}): 0.368,
#   frozenset({'f', 'g', 't'}): 0.393,
#   frozenset({'g', 'n', 't'}): 0.356,
#   frozenset({'g', 'o', 't'}): 0.35,
#   frozenset({'g', 'p', 't'}): 0.393,
#   frozenset({'g', 't', 'w'}): 0.393,
#   frozenset({'g', 't', 'y'}): 0.175,
#   frozenset({'g', 's', 't'}): 0.379,
#   frozenset({'d', 's', 'w'}): 0.313,
#   frozenset({'g', 's', 'w'}): 0.401,
#   frozenset({'g', 's', 'v'}): 0.115,
#   frozenset({'g', 't', 'v'}): 0.103,
#   frozenset({'d', 's', 'v'}): 0.192,
#   frozenset({'o', 'p', 'w', 'x'}): 0.441,
#   frozenset({'f', 'p', 'w', 'x'}): 0.464,
#   frozenset({'f', 'o', 'w', 'x'}): 0.441,
#   frozenset({'f', 'o', 'p', 'x'}): 0.451,
#   frozenset({'n', 'p', 'w', 'x'}): 0.393,
#   frozenset({'n', 'o', 'w', 'x'}): 0.37,
#   frozenset({'f', 'n', 'w', 'x'}): 0.393,
#   frozenset({'c', 'n', 'w', 'x'}): 0.317,
#   frozenset({'b', 'n', 'w', 'x'}): 0.375,
#   frozenset({'n', 'o', 'p', 'x'}): 0.38,
#   frozenset({'f', 'n', 'p', 'x'}): 0.403,
#   frozenset({'c', 'n', 'p', 'x'}): 0.327,
#   frozenset({'b', 'n', 'p', 'x'}): 0.385,
#   frozenset({'f', 'n', 'o', 'x'}): 0.38,
#   frozenset({'c', 'n', 'o', 'x'}): 0.316,
#   frozenset({'b', 'n', 'o', 'x'}): 0.362,
#   frozenset({'k', 'p', 'w', 'x'}): 0.31,
#   frozenset({'k', 'o', 'w', 'x'}): 0.301,
#   frozenset({'f', 'k', 'w', 'x'}): 0.31,
#   frozenset({'b', 'k', 'w', 'x'}): 0.301,
#   frozenset({'k', 'o', 'p', 'x'}): 0.301,
#   frozenset({'f', 'k', 'p', 'x'}): 0.31,
#   frozenset({'b', 'k', 'p', 'x'}): 0.301,
#   frozenset({'f', 'k', 'o', 'x'}): 0.301,
#   frozenset({'b', 'k', 'o', 'x'}): 0.292,
#   frozenset({'c', 'f', 'n', 'x'}): 0.327,
#   frozenset({'b', 'f', 'n', 'x'}): 0.385,
#   frozenset({'b', 'f', 'k', 'x'}): 0.301,
#   frozenset({'e', 'p', 'w', 'x'}): 0.445,
#   frozenset({'e', 'o', 'w', 'x'}): 0.422,
#   frozenset({'e', 'n', 'w', 'x'}): 0.393,
#   frozenset({'e', 'k', 'w', 'x'}): 0.31,
#   frozenset({'e', 'f', 'w', 'x'}): 0.445,
#   frozenset({'c', 'e', 'w', 'x'}): 0.369,
#   frozenset({'b', 'e', 'w', 'x'}): 0.427,
#   frozenset({'e', 'o', 'p', 'x'}): 0.432,
#   frozenset({'e', 'n', 'p', 'x'}): 0.403,
#   frozenset({'e', 'k', 'p', 'x'}): 0.31,
#   frozenset({'e', 'f', 'p', 'x'}): 0.455,
#   frozenset({'c', 'e', 'p', 'x'}): 0.379,
#   frozenset({'b', 'e', 'p', 'x'}): 0.437,
#   frozenset({'e', 'n', 'o', 'x'}): 0.38,
#   frozenset({'e', 'k', 'o', 'x'}): 0.301,
#   frozenset({'e', 'f', 'o', 'x'}): 0.432,
#   frozenset({'c', 'e', 'o', 'x'}): 0.368,
#   frozenset({'b', 'e', 'o', 'x'}): 0.414,
#   frozenset({'e', 'k', 'n', 'x'}): 0.258,
#   frozenset({'e', 'f', 'n', 'x'}): 0.403,
#   frozenset({'c', 'e', 'n', 'x'}): 0.327,
#   frozenset({'b', 'e', 'n', 'x'}): 0.385,
#   frozenset({'e', 'f', 'k', 'x'}): 0.31,
#   frozenset({'c', 'e', 'k', 'x'}): 0.268,
#   frozenset({'b', 'e', 'k', 'x'}): 0.301,
#   frozenset({'c', 'e', 'f', 'x'}): 0.379,
#   frozenset({'b', 'e', 'f', 'x'}): 0.437,
#   frozenset({'c', 'p', 'w', 'x'}): 0.388,
#   frozenset({'c', 'o', 'w', 'x'}): 0.377,
#   frozenset({'c', 'f', 'w', 'x'}): 0.388,
#   frozenset({'c', 'o', 'p', 'x'}): 0.387,
#   frozenset({'c', 'f', 'p', 'x'}): 0.398,
#   frozenset({'c', 'f', 'o', 'x'}): 0.387,
#   frozenset({'b', 'c', 'n', 'x'}): 0.309,
#   frozenset({'b', 'c', 'e', 'x'}): 0.361,
#   frozenset({'b', 'p', 'w', 'x'}): 0.446,
#   frozenset({'b', 'o', 'w', 'x'}): 0.423,
#   frozenset({'b', 'f', 'w', 'x'}): 0.446,
#   frozenset({'b', 'c', 'w', 'x'}): 0.37,
#   frozenset({'b', 'o', 'p', 'x'}): 0.433,
#   frozenset({'b', 'f', 'p', 'x'}): 0.456,
#   frozenset({'b', 'c', 'p', 'x'}): 0.38,
#   frozenset({'b', 'f', 'o', 'x'}): 0.433,
#   frozenset({'b', 'c', 'o', 'x'}): 0.369,
#   frozenset({'b', 'c', 'f', 'x'}): 0.38,
#   frozenset({'o', 'p', 'w', 'y'}): 0.556,
#   frozenset({'l', 'p', 'w', 'y'}): 0.252,
#   frozenset({'g', 'p', 'w', 'y'}): 0.289,
#   frozenset({'f', 'p', 'w', 'y'}): 0.587,
#   frozenset({'l', 'o', 'w', 'y'}): 0.252,
#   frozenset({'g', 'o', 'w', 'y'}): 0.279,
#   frozenset({'f', 'o', 'w', 'y'}): 0.556,
#   frozenset({'l', 'o', 'p', 'w'}): 0.313,
#   frozenset({'g', 'o', 'p', 'w'}): 0.506,
#   frozenset({'f', 'o', 'p', 'w'}): 0.905,
#   frozenset({'n', 'p', 'w', 'y'}): 0.499,
#   frozenset({'n', 'o', 'w', 'y'}): 0.468,
#   frozenset({'k', 'n', 'w', 'y'}): 0.332,
#   frozenset({'g', 'n', 'w', 'y'}): 0.226,
#   frozenset({'f', 'n', 'w', 'y'}): 0.499,
#   frozenset({'c', 'n', 'w', 'y'}): 0.487,
#   frozenset({'b', 'n', 'w', 'y'}): 0.47,
#   frozenset({'n', 'o', 'p', 'w'}): 0.77,
#   frozenset({'k', 'n', 'p', 'w'}): 0.567,
#   frozenset({'g', 'n', 'p', 'w'}): 0.449,
#   frozenset({'f', 'n', 'p', 'w'}): 0.848,
#   frozenset({'c', 'n', 'p', 'w'}): 0.692,
#   frozenset({'b', 'n', 'p', 'w'}): 0.805,
#   frozenset({'k', 'n', 'o', 'w'}): 0.53,
#   frozenset({'g', 'n', 'o', 'w'}): 0.406,
#   frozenset({'f', 'n', 'o', 'w'}): 0.77,
#   frozenset({'c', 'n', 'o', 'w'}): 0.643,
#   frozenset({'b', 'n', 'o', 'w'}): 0.727,
#   frozenset({'g', 'l', 'p', 'w'}): 0.163,
#   frozenset({'f', 'l', 'p', 'w'}): 0.313,
#   frozenset({'g', 'l', 'o', 'w'}): 0.163,
#   frozenset({'f', 'l', 'o', 'w'}): 0.313,
#   frozenset({'k', 'p', 'w', 'y'}): 0.42,
#   frozenset({'k', 'o', 'w', 'y'}): 0.413,
#   frozenset({'g', 'k', 'w', 'y'}): 0.208,
#   frozenset({'f', 'k', 'w', 'y'}): 0.42,
#   frozenset({'c', 'k', 'w', 'y'}): 0.419,
#   frozenset({'b', 'k', 'w', 'y'}): 0.41,
#   frozenset({'k', 'o', 'p', 'w'}): 0.631,
#   frozenset({'g', 'k', 'p', 'w'}): 0.368,
#   frozenset({'f', 'k', 'p', 'w'}): 0.668,
#   frozenset({'c', 'k', 'p', 'w'}): 0.571,
#   frozenset({'b', 'k', 'p', 'w'}): 0.65,
#   frozenset({'g', 'k', 'o', 'w'}): 0.343,
#   frozenset({'f', 'k', 'o', 'w'}): 0.631,
#   frozenset({'c', 'k', 'o', 'w'}): 0.559,
#   frozenset({'b', 'k', 'o', 'w'}): 0.613,
#   frozenset({'g', 'k', 'n', 'w'}): 0.293,
#   frozenset({'f', 'k', 'n', 'w'}): 0.567,
#   frozenset({'c', 'k', 'n', 'w'}): 0.47,
#   frozenset({'b', 'k', 'n', 'w'}): 0.549,
#   frozenset({'f', 'g', 'p', 'w'}): 0.549,
#   frozenset({'f', 'g', 'o', 'w'}): 0.506,
#   frozenset({'f', 'g', 'n', 'w'}): 0.449,
#   frozenset({'c', 'g', 'n', 'w'}): 0.313,
#   frozenset({'b', 'g', 'n', 'w'}): 0.432,
#   frozenset({'f', 'g', 'k', 'w'}): 0.368,
#   frozenset({'c', 'g', 'k', 'w'}): 0.273,
#   frozenset({'b', 'g', 'k', 'w'}): 0.36,
#   frozenset({'f', 'g', 'w', 'y'}): 0.289,
#   frozenset({'c', 'f', 'n', 'w'}): 0.692,
#   frozenset({'b', 'f', 'n', 'w'}): 0.805,
#   frozenset({'c', 'f', 'k', 'w'}): 0.571,
#   frozenset({'b', 'f', 'k', 'w'}): 0.65,
#   frozenset({'e', 'p', 'w', 'y'}): 0.587,
#   frozenset({'e', 'o', 'w', 'y'}): 0.556,
#   frozenset({'e', 'n', 'w', 'y'}): 0.499,
#   frozenset({'e', 'l', 'w', 'y'}): 0.252,
#   frozenset({'e', 'k', 'w', 'y'}): 0.42,
#   frozenset({'e', 'g', 'w', 'y'}): 0.289,
#   frozenset({'e', 'f', 'w', 'y'}): 0.587,
#   frozenset({'c', 'e', 'w', 'y'}): 0.575,
#   frozenset({'b', 'e', 'w', 'y'}): 0.558,
#   frozenset({'e', 'o', 'p', 'w'}): 0.871,
#   frozenset({'e', 'n', 'p', 'w'}): 0.848,
#   frozenset({'e', 'l', 'p', 'w'}): 0.313,
#   frozenset({'e', 'k', 'p', 'w'}): 0.668,
#   frozenset({'e', 'g', 'p', 'w'}): 0.524,
#   frozenset({'e', 'f', 'p', 'w'}): 0.949,
#   frozenset({'c', 'e', 'p', 'w'}): 0.793,
#   frozenset({'b', 'e', 'p', 'w'}): 0.906,
#   frozenset({'e', 'n', 'o', 'w'}): 0.77,
#   frozenset({'e', 'l', 'o', 'w'}): 0.313,
#   frozenset({'e', 'k', 'o', 'w'}): 0.631,
#   frozenset({'e', 'g', 'o', 'w'}): 0.481,
#   frozenset({'e', 'f', 'o', 'w'}): 0.871,
#   frozenset({'c', 'e', 'o', 'w'}): 0.744,
#   frozenset({'b', 'e', 'o', 'w'}): 0.828,
#   frozenset({'e', 'l', 'n', 'w'}): 0.222,
#   frozenset({'e', 'k', 'n', 'w'}): 0.567,
#   frozenset({'e', 'g', 'n', 'w'}): 0.449,
#   frozenset({'e', 'f', 'n', 'w'}): 0.848,
#   frozenset({'c', 'e', 'n', 'w'}): 0.692,
#   frozenset({'b', 'e', 'n', 'w'}): 0.805,
#   frozenset({'e', 'k', 'l', 'w'}): 0.269,
#   frozenset({'e', 'g', 'l', 'w'}): 0.163,
#   frozenset({'e', 'f', 'l', 'w'}): 0.313,
#   frozenset({'c', 'e', 'l', 'w'}): 0.299,
#   frozenset({'b', 'e', 'l', 'w'}): 0.312,
#   frozenset({'e', 'g', 'k', 'w'}): 0.368,
#   frozenset({'e', 'f', 'k', 'w'}): 0.668,
#   frozenset({'c', 'e', 'k', 'w'}): 0.571,
#   frozenset({'b', 'e', 'k', 'w'}): 0.65,
#   frozenset({'e', 'f', 'g', 'w'}): 0.524,
#   frozenset({'c', 'e', 'g', 'w'}): 0.388,
#   frozenset({'b', 'e', 'g', 'w'}): 0.507,
#   frozenset({'c', 'e', 'f', 'w'}): 0.793,
#   frozenset({'b', 'e', 'f', 'w'}): 0.906,
#   frozenset({'d', 'o', 'p', 'w'}): 0.38,
#   frozenset({'d', 'n', 'p', 'w'}): 0.355,
#   frozenset({'d', 'f', 'p', 'w'}): 0.386,
#   frozenset({'d', 'e', 'p', 'w'}): 0.386,
#   frozenset({'c', 'd', 'p', 'w'}): 0.37,
#   frozenset({'b', 'd', 'p', 'w'}): 0.377,
#   frozenset({'d', 'n', 'o', 'w'}): 0.349,
#   frozenset({'d', 'f', 'o', 'w'}): 0.38,
#   frozenset({'d', 'e', 'o', 'w'}): 0.38,
#   frozenset({'c', 'd', 'o', 'w'}): 0.364,
#   frozenset({'b', 'd', 'o', 'w'}): 0.371,
#   frozenset({'d', 'f', 'n', 'w'}): 0.355,
#   frozenset({'d', 'e', 'n', 'w'}): 0.355,
#   frozenset({'c', 'd', 'n', 'w'}): 0.339,
#   frozenset({'b', 'd', 'n', 'w'}): 0.346,
#   frozenset({'d', 'e', 'f', 'w'}): 0.386,
#   frozenset({'c', 'd', 'f', 'w'}): 0.37,
#   frozenset({'b', 'd', 'f', 'w'}): 0.377,
#   frozenset({'c', 'd', 'e', 'w'}): 0.37,
#   frozenset({'b', 'd', 'e', 'w'}): 0.377,
#   frozenset({'c', 'p', 'w', 'y'}): 0.575,
#   frozenset({'c', 'o', 'w', 'y'}): 0.544,
#   frozenset({'c', 'g', 'w', 'y'}): 0.289,
#   frozenset({'c', 'f', 'w', 'y'}): 0.575,
#   frozenset({'c', 'o', 'p', 'w'}): 0.778,
#   frozenset({'c', 'g', 'p', 'w'}): 0.413,
#   frozenset({'c', 'f', 'p', 'w'}): 0.827,
#   frozenset({'c', 'g', 'o', 'w'}): 0.399,
#   frozenset({'c', 'f', 'o', 'w'}): 0.778,
#   frozenset({'b', 'c', 'n', 'w'}): 0.649,
#   frozenset({'b', 'c', 'k', 'w'}): 0.553,
#   frozenset({'c', 'f', 'g', 'w'}): 0.413,
#   frozenset({'b', 'c', 'e', 'w'}): 0.75,
#   frozenset({'b', 'c', 'd', 'w'}): 0.361,
#   frozenset({'b', 'p', 'w', 'y'}): 0.558,
#   frozenset({'b', 'o', 'w', 'y'}): 0.527,
#   frozenset({'b', 'l', 'w', 'y'}): 0.251,
#   frozenset({'b', 'g', 'w', 'y'}): 0.279,
#   frozenset({'b', 'f', 'w', 'y'}): 0.558,
#   frozenset({'b', 'c', 'w', 'y'}): 0.546,
#   frozenset({'b', 'o', 'p', 'w'}): 0.862,
#   frozenset({'b', 'l', 'p', 'w'}): 0.312,
#   frozenset({'b', 'g', 'p', 'w'}): 0.532,
#   frozenset({'b', 'f', 'p', 'w'}): 0.94,
#   frozenset({'b', 'c', 'p', 'w'}): 0.784,
#   frozenset({'b', 'l', 'o', 'w'}): 0.312,
#   frozenset({'b', 'g', 'o', 'w'}): 0.489,
#   frozenset({'b', 'f', 'o', 'w'}): 0.862,
#   frozenset({'b', 'c', 'o', 'w'}): 0.735,
#   frozenset({'b', 'g', 'l', 'w'}): 0.163,
#   frozenset({'b', 'f', 'l', 'w'}): 0.312,
#   frozenset({'b', 'c', 'l', 'w'}): 0.298,
#   frozenset({'b', 'f', 'g', 'w'}): 0.532,
#   frozenset({'b', 'c', 'g', 'w'}): 0.396,
#   frozenset({'b', 'c', 'f', 'w'}): 0.784,
#   frozenset({'l', 'o', 'p', 'y'}): 0.26,
#   frozenset({'g', 'o', 'p', 'y'}): 0.279,
#   frozenset({'f', 'o', 'p', 'y'}): 0.564,
#   frozenset({'c', 'o', 'p', 'y'}): 0.552,
#   frozenset({'b', 'o', 'p', 'y'}): 0.535,
#   frozenset({'n', 'o', 'p', 'y'}): 0.476,
#   frozenset({'g', 'n', 'p', 'y'}): 0.226,
#   frozenset({'f', 'n', 'p', 'y'}): 0.507,
#   frozenset({'e', 'n', 'p', 'y'}): 0.507,
#   frozenset({'d', 'n', 'p', 'y'}): 0.241,
#   frozenset({'g', 'l', 'o', 'p'}): 0.163,
#   frozenset({'f', 'l', 'o', 'p'}): 0.33,
#   frozenset({'c', 'l', 'o', 'p'}): 0.316,
#   frozenset({'b', 'l', 'o', 'p'}): 0.329,
#   frozenset({'g', 'k', 'p', 'y'}): 0.208,
#   frozenset({'c', 'k', 'p', 'y'}): 0.419,
#   frozenset({'f', 'g', 'o', 'p'}): 0.506,
#   frozenset({'c', 'g', 'o', 'p'}): 0.399,
#   frozenset({'b', 'g', 'o', 'p'}): 0.489,
#   frozenset({'f', 'g', 'p', 'y'}): 0.289,
#   frozenset({'c', 'f', 'p', 'y'}): 0.583,
#   frozenset({'b', 'f', 'p', 'y'}): 0.566,
#   frozenset({'c', 'f', 'o', 'p'}): 0.795,
#   frozenset({'b', 'f', 'o', 'p'}): 0.879,
#   frozenset({'c', 'f', 'l', 'p'}): 0.316,
#   frozenset({'b', 'f', 'l', 'p'}): 0.329,
#   frozenset({'c', 'f', 'g', 'p'}): 0.413,
#   frozenset({'b', 'f', 'g', 'p'}): 0.532,
#   frozenset({'e', 'o', 'p', 'y'}): 0.564,
#   frozenset({'e', 'l', 'p', 'y'}): 0.26,
#   frozenset({'e', 'g', 'p', 'y'}): 0.289,
#   frozenset({'e', 'f', 'p', 'y'}): 0.595,
#   frozenset({'d', 'e', 'p', 'y'}): 0.27,
#   frozenset({'b', 'c', 'o', 'p'}): 0.752,
#   frozenset({'b', 'c', 'l', 'p'}): 0.315,
#   frozenset({'b', 'c', 'f', 'p'}): 0.801,
#   frozenset({'b', 'g', 'p', 'y'}): 0.279,
#   frozenset({'b', 'c', 'p', 'y'}): 0.554,
#   frozenset({'b', 'c', 'g', 'p'}): 0.396,
#   frozenset({'g', 'n', 'o', 'y'}): 0.216,
#   frozenset({'f', 'n', 'o', 'y'}): 0.476,
#   frozenset({'e', 'n', 'o', 'y'}): 0.476,
#   frozenset({'d', 'n', 'o', 'y'}): 0.235,
#   frozenset({'g', 'n', 'o', 'p'}): 0.406,
#   frozenset({'f', 'n', 'o', 'p'}): 0.787,
#   frozenset({'e', 'n', 'o', 'p'}): 0.787,
#   frozenset({'d', 'n', 'o', 'p'}): 0.349,
#   frozenset({'k', 'o', 'p', 'y'}): 0.413,
#   frozenset({'g', 'k', 'o', 'y'}): 0.208,
#   frozenset({'f', 'k', 'o', 'y'}): 0.413,
#   frozenset({'c', 'k', 'o', 'y'}): 0.412,
#   frozenset({'b', 'k', 'o', 'y'}): 0.403,
#   frozenset({'g', 'k', 'o', 'p'}): 0.343,
#   frozenset({'f', 'k', 'o', 'p'}): 0.631,
#   frozenset({'c', 'k', 'o', 'p'}): 0.559,
#   frozenset({'b', 'k', 'o', 'p'}): 0.613,
#   frozenset({'f', 'l', 'o', 'y'}): 0.26,
#   frozenset({'f', 'g', 'o', 'y'}): 0.279,
#   frozenset({'e', 'l', 'o', 'y'}): 0.26,
#   frozenset({'e', 'g', 'o', 'y'}): 0.279,
#   frozenset({'e', 'f', 'o', 'y'}): 0.564,
#   frozenset({'d', 'e', 'o', 'y'}): 0.264,
#   frozenset({'e', 'l', 'o', 'p'}): 0.33,
#   frozenset({'e', 'g', 'o', 'p'}): 0.481,
#   frozenset({'e', 'f', 'o', 'p'}): 0.888,
#   frozenset({'d', 'e', 'o', 'p'}): 0.38,
#   frozenset({'d', 'f', 'o', 'p'}): 0.38,
#   frozenset({'c', 'l', 'o', 'y'}): 0.25,
#   frozenset({'c', 'g', 'o', 'y'}): 0.279,
#   frozenset({'c', 'f', 'o', 'y'}): 0.552,
#   frozenset({'b', 'c', 'o', 'y'}): 0.523,
#   frozenset({'b', 'l', 'o', 'y'}): 0.259,
#   frozenset({'b', 'g', 'o', 'y'}): 0.269,
#   frozenset({'b', 'f', 'o', 'y'}): 0.535,
#   frozenset({'k', 'n', 'p', 'y'}): 0.332,
#   frozenset({'k', 'n', 'o', 'y'}): 0.325,
#   frozenset({'f', 'k', 'n', 'y'}): 0.332,
#   frozenset({'e', 'k', 'n', 'y'}): 0.332,
#   frozenset({'c', 'k', 'n', 'y'}): 0.331,
#   frozenset({'b', 'k', 'n', 'y'}): 0.322,
#   frozenset({'k', 'n', 'o', 'p'}): 0.53,
#   frozenset({'f', 'k', 'n', 'p'}): 0.567,
#   frozenset({'e', 'k', 'n', 'p'}): 0.567,
#   frozenset({'c', 'k', 'n', 'p'}): 0.47,
#   frozenset({'b', 'k', 'n', 'p'}): 0.549,
#   frozenset({'f', 'k', 'n', 'o'}): 0.53,
#   frozenset({'e', 'k', 'n', 'o'}): 0.53,
#   frozenset({'c', 'k', 'n', 'o'}): 0.458,
#   frozenset({'b', 'k', 'n', 'o'}): 0.512,
#   frozenset({'f', 'g', 'n', 'p'}): 0.449,
#   ...})

# %%
import functools

def cmp(a,b):
    if a[2] < b[2]:
        return 1
    else:
        return -1
    
    
rules = sorted(rules, key=functools.cmp_to_key(cmp))
rules
# Out:
# [(frozenset({'WB'}), frozenset({'MB'}), 0.9385964912280701),
#  (frozenset({'RB'}), frozenset({'MB'}), 0.9222222222222223),
#  (frozenset({'RB'}), frozenset({'WB'}), 0.8666666666666667),
#  (frozenset({'WB'}), frozenset({'preparation'}), 0.8596491228070176),
#  (frozenset({'RB', 'preparation'}),
#   frozenset({'MB', 'WB'}),
#   0.8513513513513514),
#  (frozenset({'RB'}), frozenset({'MB', 'WB'}), 0.8222222222222222),
#  (frozenset({'RB'}), frozenset({'preparation'}), 0.8222222222222222),
#  (frozenset({'WG'}), frozenset({'RG'}), 0.8099173553719009),
#  (frozenset({'RB', 'WB'}),
#   frozenset({'MB', 'preparation'}),
#   0.8076923076923077),
#  (frozenset({'WB'}), frozenset({'MB', 'preparation'}), 0.8070175438596491),
#  (frozenset({'MB', 'RB'}),
#   frozenset({'WB', 'preparation'}),
#   0.7590361445783133),
#  (frozenset({'RB'}), frozenset({'MB', 'preparation'}), 0.7555555555555556),
#  (frozenset({'RG'}), frozenset({'WG'}), 0.7424242424242424),
#  (frozenset({'RB'}), frozenset({'WB', 'preparation'}), 0.7333333333333334),
#  (frozenset({'MB'}), frozenset({'preparation'}), 0.7306501547987615),
#  (frozenset({'WG'}), frozenset({'MG'}), 0.7107438016528925),
#  (frozenset({'RB'}),
#   frozenset({'MB', 'WB', 'preparation'}),
#   0.7000000000000001),
#  (frozenset({'WB'}), frozenset({'RB'}), 0.6842105263157895),
#  (frozenset({'RG'}), frozenset({'MG'}), 0.6590909090909091),
#  (frozenset({'WB'}), frozenset({'MB', 'RB'}), 0.6491228070175438),
#  (frozenset({'WB', 'preparation'}),
#   frozenset({'MB', 'RB'}),
#   0.6428571428571428),
#  (frozenset({'WG'}), frozenset({'MG', 'RG'}), 0.6033057851239669),
#  (frozenset({'MB', 'WB'}),
#   frozenset({'RB', 'preparation'}),
#   0.588785046728972),
#  (frozenset({'WB'}), frozenset({'RB', 'preparation'}), 0.5789473684210527),
#  (frozenset({'RG'}), frozenset({'MG', 'WG'}), 0.553030303030303),
#  (frozenset({'WB'}),
#   frozenset({'MB', 'RB', 'preparation'}),
#   0.5526315789473684),
#  (frozenset({'MG'}), frozenset({'preparation'}), 0.5227272727272727)]

# %% [markdown]
# **根据以上规则，不难看出：**
# - 读成绩差的人，那么他其他科目的成绩大概率也差，所以要对读成绩差的人多加以关注。让他们打好基础
# - 写成绩好的人，那么读成绩大概率也好，要进行混合教育
# - 数学应该是最难的科目，应该多加以考量，哪怕其他两科成绩都好，数学成绩好的概率也不高

# %% [markdown]
# ## CBE Apriori二进制编码算法

# %%
# frozenset() 返回一个冻结的集合，冻结后集合不能再添加或删除任何元素。
import numpy as np
import pandas as pd



class node:
    def __int__(self):
        self.items = []
        self.key = 0
        self.sup = 0
    def show(self):
        print(self.items, bin(self.key), end=" ")
        try:
            print(self.sup)
        except:
            print()
            pass


def ListToNode(items):
    nodeT = node()
    nodeT.key =0
    nodeT.items = items
    for index,i in enumerate(defaultSL): # 进行编码
        if i in items:
            nodeT.key += 1 << (len(defaultSL) - index -1)
    return nodeT


def keyToList(key):
    ans =[]
    global defaultSL
    for i in range(1,len(defaultSL) +1):
        if key  & (1 << (len(defaultSL)) - i) == (1 << (len(defaultSL)) - i): # 含有第i个
            ans.append(defaultSL[i-1])
    return ans


def loadDataSet():
    '''创建一个用于测试的简单的数据集'''

    data = pd.read_csv("train.csv")
    data = data.sample(1000)
#     import copy
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data))
#     data = data.append(copy.deepcopy(data)) # 将数据扩大8倍
    print(data.shape)
    def gerDoodAndBad(score):
        ans = []

        # math judge
        if score['math score'] > 80:
            ans.append('MG')
        elif score['math score'] < 60:
            ans.append('MB')

        # reading judge
        if score['reading score'] > 85:
            ans.append('RG')
        elif score['reading score'] < 50:
            ans.append('RB')

        # writing judge
        if score['writing score'] > 85:
            ans.append('WG')
        elif score['writing score'] < 50:
            ans.append('WB')

        if score['test preparation course'] == 1:
            ans.append("preparation")

        return ans

    data['Apriori'] = data.apply(lambda x: gerDoodAndBad(x), axis=1)
#     print(data.head())

    return np.array(data['Apriori'])

def loadTest():
    testD = pd.read_csv('testData')
    testD = testD.sample(500)
    testD.shape
    npt = np.array(testD)
    npt
    return npt

# 返回只有单个元素的候选集
def createC1(dataSet):
    '''
        构建初始候选项集的列表，即所有候选项集只包含一个元素，
        C1是大小为1的所有候选项集的集合
    '''
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if [item] not in C1:
                C1.append([item])
    C1.sort()
    # return map( frozenset, C1 )
    # return [var for var in map(frozenset,C1)]
    return [frozenset(var) for var in C1]


def scanD(D, Ck, minSupport):
    '''
        计算Ck中的项集在数据集合D(记录或者transactions)中的支持度,
        返回满足最小支持度的项集的集合，和所有项集支持度信息的字典。
    '''
    print(len(Ck))

    for i in Ck:
        i.sup =0
        for item in D:
            if i.key & item.key == i.key: #与运算判断子集
                i.sup +=1
    ans =[]
    length = len(D)
    for i in Ck:
        i.sup = i.sup / length
        if i.sup >= minSupport:
            ans.append(i)
            # i.show()
    return ans



def aprioriGen(Lk, k):  # Aprior算法
    '''
        由初始候选项集的集合Lk生成新的生成候选项集，
        k表示生成的新项集中所含有的元素个数
        注意其生成的过程中，首选对每个项集按元素排序，然后每次比较两个项集，只有在前k-1项相同时才将这两项合并。这样做是因为函数并非要两两合并各个集合，那样生成的集合并非都是k+1项的。在限制项数为k+1的前提下，只有在前k-1项相同、最后一项不相同的情况下合并才为所需要的新候选项集。
    '''

    global twoDif

    retList = []
    lenLk = len(Lk)
    nowSet = set()
    for i in range(lenLk):
        for j in range(i + 1, lenLk):

            a = Lk[i]
            b = Lk[j]
            t = a.key ^ b.key
            #要注意候选集以及去重的问题
            if t in twoDif:

                
                tkey = a.key | b.key
                if tkey not in nowSet:
                    nodeT = node()
                    nodeT.key = tkey
                    nowSet.add(nodeT.key)
                    # a.show()
                    # b.show()
#                     nodeT.items = keyToList(nodeT.key)  #生成新的items
                    retList.append(nodeT)
                else:
                    pass

    return retList


def apriori(dataSet, minSupport=0.5):
    """
    该函数为Apriori算法的主函数，按照前述伪代码的逻辑执行。Ck表示项数为k的候选项集，最初的C1通过createC1()函数生成。Lk表示项数为k的频繁项集，supK为其支持度，Lk和supK由scanD()函数通过Ck计算而来。
    :param dataSet:
    :param minSupport:
    :return:
    """
    # C1 = createC1(dataSet)  # 构建初始候选项集C1  [frozenset({1}), frozenset({2}), frozenset({3}), frozenset({4}), frozenset({5})]
    global defaultSL
    global defaultS

#     print(defaultSL)
    C1 = [ListToNode([i]) for i in defaultSL]


    # D = [set(var) for var in dataSet]  # 集合化数据集

    F1 = scanD(dataSet, C1, minSupport)  # 构建初始的频繁项集，即所有项集只有一个元素

    # print()
    L = [F1]
    k = 2  # 项集应该含有2个元素，所以 k=2

    while (len(L[k - 2]) > 0):
        t= time.time()
        Ck = aprioriGen(L[k - 2], k) # 计算候选集
        print(f'gen coast:{time.time() - t:.8f}s')
        t = time.time()
        
        Fk= scanD(dataSet, Ck, minSupport) # 筛选最小支持度的频繁项集
        print(f'scan coast:{time.time() - t:.8f}s')

        L.append(Fk)  # 将符合最小支持度要求的项集加入L
        k += 1  # 新生成的项集中的元素个数应不断增加
    return L  # 返回所有满足条件的频繁项集的列表，和所有候选项集的支持度信息


def calcConf(freqSet, H, supportData, brl, minConf=0.7):  # 规则生成与评价
    '''
        计算规则的可信度，返回满足最小可信度的规则。
        freqSet(frozenset):频繁项集
        H(frozenset):频繁项集中所有的元素
        supportData(dic):频繁项集中所有元素的支持度
        brl(tuple):满足可信度条件的关联规则
        minConf(float):最小可信度
    '''
    prunedH = []
    for conseq in H:
        conf = supportData[freqSet] / supportData[freqSet - conseq]
        if conf >= minConf:
            print(freqSet - conseq, '-->', conseq, 'conf:', conf)
            brl.append((freqSet - conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH


def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    '''
        对频繁项集中元素超过2的项集进行合并。
        freqSet(frozenset):频繁项集
        H(frozenset):频繁项集中的所有元素，即可以出现在规则右部的元素
        supportData(dict):所有项集的支持度信息
        brl(tuple):生成的规则
    '''
    m = len(H[0])
    if len(freqSet) > m + 1:  # 查看频繁项集是否足够大，以到于移除大小为 m的子集，否则继续生成m+1大小的频繁项集
        Hmp1 = aprioriGen(H, m + 1)
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)  # 对于新生成的m+1大小的频繁项集，计算新生成的关联规则的右则的集合
        if len(Hmp1) > 1:  # 如果不止一条规则满足要求（新生成的关联规则的右则的集合的大小大于1），进一步递归合并，
            # 这样做的结果就是会有“[1|多]->多”(右边只会是“多”，因为合并的本质是频繁子项集变大，
            # 而calcConf函数的关联结果的右侧就是频繁子项集）的关联结果
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)


def generateRules(L, supportData, minConf=0.7):
    '''
        根据频繁项集和最小可信度生成规则。
        L(list):存储频繁项集
        supportData(dict):存储着所有项集（不仅仅是频繁项集）的支持度
        minConf(float):最小可信度
    '''
    bigRuleList = []
    for i in range(1, len(L)):
        for freqSet in L[i]:  # 对于每一个频繁项集的集合freqSet
            H1 = [frozenset([item]) for item in freqSet]
            if i > 1:  # 如果频繁项集中的元素个数大于2，需要进一步合并，这样做的结果就是会有“[1|多]->多”(右边只会是“多”，
                # 因为合并的本质是频繁子项集变大，而calcConf函数的关联结果的右侧就是频繁子项集），的关联结果
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)

    sorted(bigRuleList)
    return bigRuleList

# %%
defaultS = set()  # 存储所有单项的集合
myDat = loadTest()  # 导入数据集
for i in myDat:
    for j in i:
        if j not in defaultS:
            defaultS.add(j)
defaultSL = list(defaultS)
defaultSL = sorted(defaultSL) # 把所有单项计算出来并排序，形成默认顺序，方便后面进行二进制编码
print(defaultSL, len(defaultSL))
Items = []



#对项集进行二进制编码
for items in myDat:
    nodeT = node()
    nodeT.key =0
    nodeT.items = items
    for index,i in enumerate(defaultSL): # 进行编码
        if i in items:
            nodeT.key += 1 << (len(defaultSL) - index -1)
    Items.append(nodeT)
    # print(items, bin(nodeT.key))
# Out:
# ['?', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', 'w', 'x', 'y'] 23

# %% [markdown]
# 得到默认编码序列['MB', 'MG', 'RB', 'RG', 'WB', 'WG', 'preparation']

# %%
twoDif =set() # 计算仅仅两个不同时的二进制集合
length = len(defaultSL)
for i in range(length):
    for j in range(length):
        if i != j:
            t=0
#             print(i,j)
            t = 1<<(i) 
            t+=1<<(j)
#             print(bin(t))
            twoDif.add(t)
for i in twoDif:
    print(bin(i))
# Out:
# 0b11000000000
# 0b1000000001
# 0b10000000001
# 0b11
# 0b100000000001
# 0b101
# 0b1000000000001
# 0b10000000000001
# 0b100000000000001
# 0b1001
# 0b1000000000000001
# 0b10000000000000001
# 0b10000000000000000001
# 0b1000000000000000001
# 0b1010
# 0b1100
# 0b1000000001000
# 0b10001
# 0b10010
# 0b100000000000000010
# 0b10100
# 0b100000000000100
# 0b1000000000000100
# 0b10000000000000100
# 0b100000000000000100
# 0b1000000000000000100
# 0b10000000000000000100
# 0b1000000010
# 0b100000000000000000100
# 0b1000000000000000000100
# 0b10000000000000000000100
# 0b100000000000000000001
# 0b1000000000000000000001
# 0b100001
# 0b10000000000000000000001
# 0b110
# 0b100010
# 0b100100
# 0b1000000100
# 0b1000100000
# 0b101000
# 0b100000000001000
# 0b1000000000001000
# 0b10000000010
# 0b10000000000001000
# 0b100000000000001000
# 0b1000000000000001000
# 0b10000000000000001000
# 0b100000000000000001000
# 0b1000000000000000001000
# 0b10000000000000000001000
# 0b110000
# 0b10000000100
# 0b1100000000000000
# 0b10000000000000000010
# 0b100000000000000000010
# 0b1000000000000000000010
# 0b10000000000000000000010
# 0b1000001000
# 0b1001000000
# 0b1000001
# 0b1000010
# 0b10001000000
# 0b1000100
# 0b100001000000
# 0b1000001000000
# 0b10000001000000
# 0b100000000000010
# 0b1001000
# 0b10000001000
# 0b100000000010
# 0b1000000100000000000
# 0b10010000000000000000
# 0b100010000000000000000
# 0b1000010000000000000
# 0b1010000
# 0b100000000010000
# 0b1000000000010000
# 0b10000000000010000
# 0b100000000000010000
# 0b100000000100
# 0b1000000000000010000
# 0b10000000000000010000
# 0b1000000000000010
# 0b100000000000000010000
# 0b1000000000000000010000
# 0b10000000001000000000
# 0b100000000001000000000
# 0b1000000000001000000000
# 0b10000000000001000000000
# 0b10100000000000000
# 0b1100000
# 0b1000010000
# 0b110000000000
# 0b101000000000000000000
# 0b100001000000000
# 0b11000000000000000
# 0b100000001000
# 0b1010000000000000000
# 0b1010000000000000000000
# 0b10000010000
# 0b1000001000000000
# 0b10000000000000010
# 0b11000
# 0b1100000000000000000000
# 0b10000100000000000000
# 0b1010000000
# 0b10000001
# 0b10000010
# 0b10010000000
# 0b10000100
# 0b100010000000
# 0b1000010000000
# 0b10000010000000
# 0b10001000
# 0b100000010000000
# 0b1000000010000000
# 0b1000000000010
# 0b10000000010000000
# 0b100000000010000000
# 0b1000000000010000000
# 0b10000001000000000000
# 0b10010000
# 0b100000010000
# 0b1001000000000
# 0b100000001000000000000
# 0b100000100000000000000
# 0b1000000000100
# 0b10000001000000000
# 0b100100000000000000
# 0b10000000000010000000
# 0b100000000000010000000
# 0b1000000000000010000000
# 0b10000000000000010000000
# 0b101000000000000
# 0b100000000000000001
# 0b10100000
# 0b1010000000000
# 0b100000000100000
# 0b1000000000100000
# 0b10000000000100000
# 0b100000000000100000
# 0b1000000000000100000
# 0b10000000000000100000
# 0b100000000000000100000
# 0b1000000000000000100000
# 0b10000000000000000100000
# 0b10000000010000000000
# 0b100000000010000000000
# 0b1000000000010000000000
# 0b10000000000010000000000
# 0b1001000000000000
# 0b1000000100000000000000
# 0b10010000000000000000000
# 0b10100000000000000000
# 0b100010000000000
# 0b10100000000000000000000
# 0b11000000
# 0b1100000000000
# 0b10000100000
# 0b100100000000000000000
# 0b110000000000000000
# 0b1000010000000000
# 0b10001000000000000
# 0b10001000000000000000
# 0b1000000010000
# 0b100000001000000000
# 0b11000000000000000000000
# 0b100001000000000000000
# 0b100000100000
# 0b1000100000000000000000
# 0b10000010000000000
# 0b10000000100000000000000
# 0b1000000001000000000000
# 0b1100000000
# 0b100000001
# 0b100000010
# 0b10100000000
# 0b100000100
# 0b100100000000
# 0b1000100000000
# 0b10000100000000
# 0b100001000
# 0b100000100000000
# 0b1000000100000000
# 0b10000000000010
# 0b10000000100000000
# 0b100000000100000000
# 0b1000000000100000000
# 0b10000000000100000000
# 0b100010000
# 0b100000000000100000000
# 0b1000000000000100000000
# 0b10001000000000
# 0b10000010000000000000
# 0b10000000000100
# 0b100000010000000000000
# 0b1000000010000000000000
# 0b1000100000000000000
# 0b1000001000000000000000
# 0b110000000000000
# 0b100100000
# 0b10010000000000
# 0b1000000100000
# 0b10000100000000000000000
# 0b1001000000000000000
# 0b100000010000000000
# 0b10000000001000
# 0b10000000000000100000000
# 0b1010000000000000
# 0b10000000001000000000000
# 0b100001000000000000
# 0b1000000000000000010
# 0b11000000000000000000
# 0b101000000
# 0b10100000000000
# 0b10000001000000000000000
# 0b100000001000000
# 0b1000000001000000
# 0b10000000001000000
# 0b100000000001000000
# 0b1000000000001000000
# 0b10000000000001000000
# 0b100000000000001000000
# 0b1000000000000001000000
# 0b10000000000000001000000
# 0b10000000100000000000
# 0b100000000100000000000
# 0b1000000000100000000000
# 0b10000000000100000000000
# 0b10010000000000000
# 0b10000000010000
# 0b1000000001000000000
# 0b100100000000000
# 0b1001000000000000000000
# 0b1000100000000000
# 0b110000000
# 0b11000000000000
# 0b1100000000000000000
# 0b10000100000000000
# 0b1000001000000000000
# 0b110000000000000000000
# 0b100010000000000000
# 0b10000000000000000010000
# 0b101000000000
# 0b1000010000000000000000
# 0b10000000100000
# 0b1000000010000000000
# 0b10001000000000000000000
# 0b101000000000000000
# 0b10000000010000000000000
# 0b100000100000000000
# 0b10000010000000000000000

# %%
len(Items)
# Out:
# 3000

# %%
import time
t = time.time()

L = apriori(Items, 0.3)  # 选择频繁项集
# print(u"频繁项集L：")
# for li in L:
#     for i in li:
#         i.show()
print(f'total coast:{time.time() - t:.8f}s')
# Out:
# 23
# gen coast:0.00000000s
# 136
# scan coast:0.06391072s
# gen coast:0.00799584s
# 618
# scan coast:0.17588043s
# gen coast:0.08877039s
# 1781
# scan coast:0.49010301s
# gen coast:0.41601825s
# 3449
# scan coast:0.91635227s
# gen coast:0.85210156s
# 4609
# scan coast:1.01959419s
# gen coast:0.88801241s
# 4272
# scan coast:0.92839384s
# gen coast:0.47057652s
# 2700
# scan coast:0.60843277s
# gen coast:0.12788963s
# 1109
# scan coast:0.25730324s
# gen coast:0.01602626s
# 267
# scan coast:0.05670357s
# gen coast:0.00000000s
# 29
# scan coast:0.00000000s
# gen coast:0.00000000s
# 0
# scan coast:0.00000000s
# total coast:7.41680861s

# %% [markdown]
# ### 这里对比原生的Apriori算法，可以看出答案是一样的。正确
#
# ### 关于运行速度对比
# - 如果采用原生的教学数据集看不出太大差别，因为数据集很小。
# - 但是如果采用稍微正常一点的不是很稠密的数据集，不难看出。随着最小支持度的减小，二者的差别越来越大
# - 这里的数据集采用mushroom
#
# ### 关于运行效率分析
# 这里的数据集特征，
# - 总计8123条数据,23个特征
# - 如果数据条数足够大的时候，时间主要集中在gen上，这时候二进制编码的效率就上来了
# - 当特征太少的时候，二者跑不出太大区别，因为基本都是单项集scan和查找候选集都没有太大差别
#
# ### 结果
#
# 当数据集为500,23特征，支持度为0.3
# - 经典Apriori：21.2s
# - 二进制Apriori：5.8s
#
# 3000,23特征，支持度为0.3
# - 经典Apriori：分钟了
# - 二进制Apriori：30.2s
